# %% [markdown]
# ## 영화 추천을 위한 영화 데이터 및 리뷰정보 크롤링
#
# 1. 왓차피디아
# - https://pedia.watcha.com/ko-KR
#
# 2. 영화개봉정보 - 영화관입장권통합전산망
# - https://www.kobis.or.kr/kobis/business/mast/mvie/searchMovieList.do#none

# %%
# !pip freeze > requirements.txt
# !pip install -r requirements.txt

# %%
import pandas as pd
import numpy as np

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

from bs4 import BeautifulSoup
import requests


from urllib.parse import quote

import time
#time.sleep을 위한 난수생성
import random

from tqdm import tqdm

# text 전처리
import re

# 마우스 커서 이동을 위한 패키지
import pyautogui

# %%
movie = pd.read_excel('data/영화정보 리스트_2024-03-19.xls', header=4)
movie.head(5)
# Out:
#             영화명                      영화명(영문)    제작연도 제작국가  유형      장르 제작상태  \
# 0     남은 인생 10년            The Last 10 Years  2022.0   일본  장편  멜로/로맨스   개봉
# 1   달짝지근해: 7510                   HONEYSWEET  2022.0   한국  장편     코미디   개봉
# 2            폭로                       Havana  2022.0   한국  장편  범죄,스릴러   개봉
# 3  어디로 가고 싶으신가요  Where Would You Like to Go?  2023.0   한국  장편     드라마   개봉
# 4   만해 한용운 님의침묵               Silence of Thy  2022.0   한국  장편     드라마   개봉
#
#          감독          제작사
# 0  후지이 미치히토          NaN
# 1        이한       (주)무비락
# 2       홍용호  (주)로그라인스튜디오
# 3       김희정     (주)인벤트스톤
# 4       한명구   주식회사 시네마서울

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1547 entries, 0 to 1546
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   영화명      1547 non-null   object
#  1   영화명(영문)  794 non-null    object
#  2   제작연도     1516 non-null   float64
#  3   제작국가     1547 non-null   object
#  4   유형       1547 non-null   object
#  5   장르       1493 non-null   object
#  6   제작상태     1546 non-null   object
#  7   감독       1242 non-null   object
#  8   제작사      632 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 108.9+ KB

# %%
movie['장르'].fillna('', inplace=True)
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_10360\3068823807.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   movie['장르'].fillna('', inplace=True)

# %%
movie = movie[~movie['장르'].str.contains('성인')]

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 775 entries, 0 to 1546
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   영화명      775 non-null    object
#  1   영화명(영문)  658 non-null    object
#  2   제작연도     753 non-null    float64
#  3   제작국가     775 non-null    object
#  4   유형       775 non-null    object
#  5   장르       775 non-null    object
#  6   제작상태     775 non-null    object
#  7   감독       624 non-null    object
#  8   제작사      257 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 60.5+ KB

# %%
movie['제작연도'].unique()
# Out:
# array([2022., 2023., 2020., 2021., 2004.,   nan, 2019., 1995., 1990.,
#        1988., 1964., 1980., 2018., 2015., 1948., 1999., 1996.])

# %%
movie['제작연도'] =  movie['제작연도'].fillna(0).apply(lambda x: str(int(np.round(x))))

# %%
movie['장르'].unique()
# Out:
# array(['멜로/로맨스', '코미디', '범죄,스릴러', '드라마', '코미디,드라마,멜로/로맨스', '다큐멘터리',
#        '사극,드라마', '멜로/로맨스,판타지,드라마', '판타지,드라마', '드라마,멜로/로맨스,범죄',
#        '멜로/로맨스,코미디', '드라마,기타', '사극,액션', '드라마,멜로/로맨스,뮤지컬,공연', '애니메이션',
#        '드라마,멜로/로맨스', '드라마,사극,스릴러,전쟁', '코미디,드라마', '공포(호러),코미디',
#        '미스터리,드라마,스릴러', '드라마,미스터리', '드라마,액션,범죄', 'SF,드라마,스릴러',
#        '드라마,판타지,멜로/로맨스', '공연,다큐멘터리', '', '미스터리,범죄,드라마', '스릴러',
#        '멜로/로맨스,드라마', '공연', '공포(호러)', '멜로/로맨스,드라마,판타지', '드라마,범죄', '범죄',
#        '판타지,어드벤처,애니메이션', '전쟁,액션', '스릴러,멜로/로맨스', '공포(호러),미스터리',
#        '액션,어드벤처,판타지', '미스터리,스릴러,드라마', '액션', 'SF,액션', '범죄,액션',
#        '공포(호러),스릴러', '코미디,액션', '미스터리,스릴러', '어드벤처,드라마,코미디',
#        '애니메이션,어드벤처,판타지', '스릴러,드라마,코미디', '전쟁,드라마', '드라마,멜로/로맨스,가족',
#        '액션,드라마,스릴러', '액션,드라마', '애니메이션,어드벤처', '범죄,드라마,스릴러',
#        '애니메이션,판타지,어드벤처', '액션,스릴러,전쟁', '미스터리,공포(호러)', 'SF,스릴러',
#        '다큐멘터리,드라마,가족', '판타지,액션', '다큐멘터리,범죄', '범죄,액션,스릴러', '스릴러,공포(호러)',
#        'SF,액션,드라마', '서부극(웨스턴),코미디,액션', '액션,어드벤처,SF,스릴러', '액션,스릴러',
#        '액션,범죄', '드라마,코미디', '액션,SF', 'SF,멜로/로맨스,가족', 'SF',
#        '애니메이션,액션,코미디,어드벤처', '기타', '범죄,드라마', '멜로/로맨스,코미디,드라마,판타지',
#        '미스터리,드라마', '판타지,멜로/로맨스', '드라마,멜로/로맨스,코미디', '스릴러,드라마',
#        '전쟁,공포(호러),액션', '스릴러,액션', '드라마,액션,전쟁', '미스터리',
#        '범죄,미스터리,스릴러,공포(호러)', '드라마,스릴러', '범죄,멜로/로맨스,스릴러', '스릴러,기타',
#        '액션,스릴러,범죄', '드라마,뮤지컬', '애니메이션,어드벤처,액션', '애니메이션,어드벤처,코미디,가족',
#        '공포(호러),미스터리,스릴러', '어드벤처,공포(호러)', '액션,드라마,전쟁', '액션,스릴러,어드벤처',
#        'SF,어드벤처', '공포(호러),SF,스릴러', '전쟁,액션,범죄', '멜로/로맨스,코미디,드라마', '드라마,가족',
#        '드라마,가족,코미디', '드라마,액션', '애니메이션,드라마,멜로/로맨스', '어드벤처,액션',
#        'SF,판타지,코미디', '가족,드라마', '애니메이션,판타지,드라마', '액션,판타지',
#        '범죄,드라마,스릴러,공포(호러)', '액션,코미디,드라마', '뮤지컬,가족,판타지,멜로/로맨스', '공연,뮤지컬',
#        '애니메이션,액션,어드벤처', '어드벤처,미스터리,SF', '애니메이션,어드벤처,코미디', '액션,공포(호러)',
#        '애니메이션,미스터리,판타지', '액션,공포(호러),드라마', '코미디,판타지,공포(호러)', '액션,SF,스릴러',
#        '전쟁,스릴러', '액션,멜로/로맨스,코미디', '애니메이션,멜로/로맨스', '판타지,미스터리,스릴러',
#        '애니메이션,어드벤처,가족', '액션,어드벤처', '액션,코미디', '액션,사극', '뮤지컬,코미디,멜로/로맨스,공연',
#        '공포(호러),스릴러,미스터리', '가족', '코미디,공포(호러)', '액션,전쟁', '멜로/로맨스,SF',
#        '애니메이션,판타지,액션', '뮤지컬', '공포(호러),스릴러,코미디', '애니메이션,가족,어드벤처',
#        '가족,뮤지컬,드라마', '드라마,코미디,판타지', '애니메이션,판타지', '뮤지컬,공연'], dtype=object)

# %%
movie_list = movie['영화명'].to_list()
movie_list
# Out:
# ['남은 인생 10년',
#  '달짝지근해: 7510',
#  '폭로',
#  '어디로 가고 싶으신가요',
#  '만해 한용운 님의침묵',
#  '나비효과',
#  '울지마 엄마',
#  '연악: 나의 운명',
#  '어느 날 그녀가 우주에서',
#  '3일의 휴가',
#  '흠뻑채운 젖은 속살',
#  '탐욕에 젖은 섹스',
#  '탐욕스런 동침',
#  '타락한 유부녀의 유혹',
#  '유부녀의 욕망 속살',
#  '유부녀의 비밀스런 사정',
#  '옆집 유부녀의 속사정',
#  '아버님이 채운 유부녀',
#  '자우림, 더 원더랜드',
#  '위험사회',
#  '서울의 봄',
#  '싱글 인 서울',
#  '콘크리트 유토피아',
#  '노량: 죽음의 바다',
#  '사랑의 불시착: 라이브 인 서울',
#  '두다다쿵: 후후섬의 비밀',
#  '나의 피투성이 연인',
#  '듣보인간의 생존신고',
#  '어른 김장하',
#  '돼지의 최후',
#  '겨울 이야기',
#  '드림',
#  '손',
#  '비밀',
#  '신세계로부터',
#  '솔라 플라워',
#  '르네에게',
#  '익스트림 페스티벌',
#  '다음 소희',
#  '괴인',
#  '돈 룩 디퍼',
#  '사랑엔 정의가 없다',
#  '그대들은 어떻게 살 것인가',
#  '청춘 돼지는 외출하는 여동생의 꿈을 꾸지 않는다',
#  '너와 나',
#  '말하고 싶은 비밀',
#  '상견니',
#  '류이치 사카모토: 오퍼스',
#  '절해고도',
#  '미끼',
#  '도티와 영원의 탑',
#  '사위 사랑은 장모 4',
#  '여배우들 : 바꿔할래?',
#  '그녀의 취미생활',
#  '라방',
#  '오늘 출가합니다',
#  '리향',
#  '자매의 스와핑',
#  '참을 수 없는 탐욕',
#  '바지 내린 욕정녀',
#  '몸으로 받은 상사',
#  '우리 돈 벌레',
#  '옆집 아저씨와 같은 침대에 누워 있다',
#  '새엄마 잠깐 거긴 안돼',
#  '멋대로 들어온 돌싱녀 : 하고 싶어요',
#  '남편 말고 의붓아들 : 속궁합이 잘 맞아',
#  '쉽게 넣는 그녀 무삭제판',
#  '가랑이 채운 처형 무삭제판',
#  '르네상스 필름 바이 비욘세',
#  '아이엠 장모에요',
#  '며느리의 반복 된 숨소리 : 나를 흥분하게 해',
#  '나 혼자만 레벨업 : 프리뷰',
#  '착한 형수 6',
#  '반응 잘하는 양아들 속사정 있는 여관밤',
#  '신체모음.zip',
#  '너의 순간',
#  '30일',
#  '어쩌면 우린 헤어졌는지 모른다',
#  '캐리와 슈퍼콜라',
#  '별 볼일 없는 인생',
#  '소년들',
#  '티처스 라운지',
#  '바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!',
#  '2만 종의 벌',
#  '빅슬립',
#  '여대생 하숙집',
#  '비닐하우스',
#  '두 사람을 위한 식탁',
#  '물비늘',
#  '사이비 여신도의 성생활',
#  '신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~',
#  '크레센도',
#  '사랑은 낙엽을 타고',
#  '문바운드',
#  '디셈버',
#  '리빙: 어떤 인생',
#  '더 퍼스트 슬램덩크',
#  '웨스턴 프론트: 서부전선',
#  '언더 유어 베드',
#  '치악산',
#  '힐마 아프 클린트 - 미래를 위한 그림',
#  '트롤: 밴드 투게더',
#  '아쿠아맨과 로스트 킹덤',
#  '화란',
#  '세계를 뒤흔든 43일',
#  '제시는 그때 스무살이었다',
#  '매트',
#  '매드 하이디',
#  '라스트 서바이버',
#  '약속',
#  '조이랜드',
#  '인디펜던스 나이트',
#  '엘리자벳과 나',
#  '쏘우 X',
#  '뽀로로 극장판 슈퍼스타 대모험',
#  '무빙 포 워드',
#  '노 엑시트',
#  '밀수',
#  '찬란한 나의 복수',
#  '오픈 더 도어',
#  '교토에서 온 편지',
#  '지옥만세',
#  '강다니엘: 마이 퍼레이드',
#  '2퍼센트',
#  '제비',
#  '홈그라운드',
#  '스즈메의 문단속',
#  '안녕, 내일 또 만나',
#  '매직 프린세스: 얼음 괴물과 사라진 열쇠의 비밀',
#  '렛 미 고',
#  '사랑의 고고학',
#  '믿을 수 있는 사람',
#  '뉴 노멀',
#  '5시부터 7시까지의 주희',
#  '수라',
#  '엄마의 땅: 그리샤와 숲의 주인',
#  '우리의 하루',
#  '독친',
#  '엔시티 네이션 : 투 더 월드 인 시네마',
#  '신 울트라맨',
#  '백남준: 달은 가장 오래된 TV',
#  '마에스트로 번스타인',
#  '룩앳미 터치미 키스미',
#  '뉴클리어 나우',
#  '나폴레옹',
#  '여섯 개의 밤',
#  '무경계',
#  '신입사원: 더 무비',
#  '만분의 일초',
#  '여덟 번째 감각',
#  '보호자',
#  '극장판 우당탕탕 은하안전단: 진정한 용기!',
#  '스노우 폭스: 썰매개가 될 거야!',
#  '명탐정코난: 흑철의 어영',
#  '수운잡방',
#  '동백정원',
#  '내 아내를 빌려드립니다',
#  '레슬리에게',
#  '아줌마',
#  '스크린골프_옆 방 커플과 스와핑',
#  '비욘드 라이브 더 무비\xa0-\xa0태민\xa0:\xa0엔.지.디.에이',
#  '은밀한 미용실2',
#  '물 많은 여자 2',
#  '젖큰 옆집 누나',
#  '맛있는 외도:몰래 하는 섹스',
#  '넘치는 욕정녀 무삭제판',
#  '호의가 계속되면 남편이 바뀐다',
#  '새엄마 허락해 줘 : 오늘부터 1일',
#  '부장님 제가 세워드릴게요',
#  '물 많은 요가 강사의 뒷문 개방',
#  '손기술이 죽여줘 10초 컷!',
#  '유혹하는 형수들:괜찮아 안전한 날이야',
#  '아내의 팬티에서 다른남자의 냄새가 난다',
#  '쌍둥이 자매 남편공유',
#  '마인드 좋은 유부녀의 질 좋은 내조',
#  '질 좋은 스킬:남편 출장 간 옆집부인',
#  '잘하는 여선배 젖은 스타킹',
#  '욕구불만 사모님:정기 다 털린 날',
#  '쉽게 넣는 그녀',
#  '남편은 인싸 시부는 아싸',
#  '가랑이 채운 처형',
#  '언니 남친에게 엉덩이 털린 날',
#  '많이 만져본 누나의 손기술',
#  '떡 주는 셰어하우스:노팬티 유이',
#  '하고보니 처제:뒷태가 죽여줘',
#  '아들이 잠에 들면 며느리는 내 방으로 찾아온다',
#  '너무 잘 하는 형부:수컷의 본능',
#  '흑인에게 미친 여친 무삭제판',
#  '아내의 스탯 7싸 1도움',
#  '속 깊은 형수',
#  '새엄마랑 사랑에 빠진게 죄는 아니잖아',
#  '출장 도우미',
#  '귀신이 싼다 무삭제판',
#  '친구 여친이 내 물건을 만졌다! 무삭제판',
#  '여직원들 ： 2대2 스와핑',
#  '사형에 이르는 병',
#  '시아버지 남편에게는 비밀로 해요',
#  '세이퍼 앳 홈',
#  '새엄마 끝 : 애인 시작',
#  '사육의 덫에 걸린 육덕 어시던트',
#  '궁극의 섹스 : 오빠 1분 컷 해줄게',
#  '컨트리 카바레',
#  '1947 보스톤',
#  '데블스 맨: 제1특전단',
#  '버텨내고 존재하기',
#  '이빨요정 비올레타: 요정나라로 돌아갈래!',
#  '아워 프렌드',
#  '마크로스 플러스 -무비 에디션-',
#  '극장판 파워 디지몬 더 비기닝',
#  '녹야',
#  '괴물',
#  '여직원들 ： 직장 연애사 3',
#  '음란치료사의 참교육 무삭제판',
#  '구멍 속 따뜻한 그녀',
#  '골프치는 여자들_밤마다 굿샷',
#  '총각파티 ： 은밀한 서비스',
#  '너무 급한 며느리 무삭제판',
#  '쾌락탐구생활',
#  '그림자 고백',
#  '사채소년',
#  '애프터썬',
#  '콘돌스 네스트',
#  '비투비 타임 : 비투게더 더 무비',
#  '마루이 비디오',
#  '애스터로이드 시티',
#  '키리에의 노래',
#  '키리에의 노래: 디렉터스 컷',
#  '욕정 채운 유부녀 무삭제판',
#  '욕정녀의 젖은 속옷 무삭제판',
#  '이불속 욕정해결사 무삭제판',
#  '아주버님을 맛본 아내',
#  '아내의 맛 무삭제판',
#  '성스러운 며느리 무삭제판',
#  '형 와이프의 젖은 손길',
#  '새엄마는 관계중',
#  '비공식작전',
#  '간호사는 욕정충전기 무삭제판',
#  '테일러 스위프트 디 에라스 투어',
#  '걸스 인 원더랜드 : 벤타엑스 브이알 뮤직시네마 02',
#  '열려버린 판도라의 봉지:임자 만난 엉덩이',
#  '브랫:나를 만족 시켜줘',
#  '미대생 손길에 자지러진 새아빠',
#  '육체 가정부:너무 쉽게 열어주네',
#  '새엄마 처음부터 좋아했어',
#  '어게인 5년째 첫날밤',
#  '타임코드 57',
#  '본 투 플라이',
#  '퀴어 마이 프렌즈',
#  '너는 내 아들',
#  '천박사 퇴마 연구소: 설경의 비밀',
#  '용감한 시민',
#  '프리 철수 리',
#  '스트리머',
#  '나는 여기에 있다',
#  '서태지 25주년 라이브 타임: 트래블러',
#  '스프린터',
#  '티빙 오리지널 운수 오진 날',
#  '느티나무 아래',
#  '멍뭉이',
#  '마이 대디',
#  '더 문',
#  '잔고: 분노의 적자',
#  '헝거게임: 노래하는 새와 뱀의 발라드',
#  '프레디의 피자가게',
#  '여귀교- 저주를 부르는 게임',
#  '세일즈걸',
#  '브루스 윌리스의 라스트 미션: 데이 투 다이',
#  '더 챔피언',
#  '더 와일드: 야수들의 전쟁',
#  '너를 부르는 시간 ',
#  '금의 나라 물의 나라',
#  '다이브: 100 피트 추락',
#  '이니셰린의 밴시',
#  '백지영 콘서트 인 시네마',
#  '톡 투 미',
#  '화사한 그녀',
#  '물귀신',
#  '더 마블스',
#  '너를 줍다',
#  '거미줄 (악어와 악어새)',
#  '마인드 유니버스',
#  '범죄도시3',
#  '마이 샤이니 월드',
#  '작은정원',
#  '앵그리 애니',
#  '시뮬런트',
#  '붉은 장미의 추억',
#  '극장판 아이돌리쉬 세븐; 라이브 4비트 비욘드 더 피리어드 - 데이 2',
#  '퀵샌드',
#  '원 모어 찬스',
#  '우당탕탕 경찰 음악대',
#  '바비 IMAX',
#  '롱디',
#  '씰벤져스 : 용감한 바다특공대',
#  '시수',
#  '람빅, 시간과 열정의 맥주',
#  '킹 오브 뉴욕',
#  '달리랜드',
#  '마브카 : 숲의 노래',
#  '빌리와 용감한 녀석들: 황금 달걀 구조대',
#  '비더원: 비퍼스트 더 무비',
#  '킹 오브 킬러스',
#  '팟 제너레이션',
#  '유앤미앤미',
#  '더 킬러',
#  '괴담만찬',
#  '사나: 저주의 아이',
#  '블루 자이언트',
#  '플라워 킬링 문',
#  '모딜리아니',
#  '더 도터',
#  '극장판 아이돌리쉬 세븐; 라이브 4비트 비욘드 더 피리어드 - 데이 1',
#  '세이 예스 어게인',
#  '익스펜더블 4',
#  '엑소시스트: 믿는 자',
#  '바람 따라 만나리 : 김호중의 계절',
#  '이누부!',
#  '빈틈없는 사이',
#  '거룩한 술꾼의 전설',
#  '기억해, 우리가 사랑한 시간',
#  '봉태리',
#  '만강홍: 사라진 밀서',
#  '나의 행복한 결혼',
#  '바빌론',
#  '퍼피 구조대: 더 마이티 무비',
#  '극장판 엉덩이 탐정: 미스터리 가면 ~최강의 대결',
#  '스크래퍼',
#  '크리에이터',
#  '드림쏭2',
#  '당나귀 EO',
#  '키네마의 신',
#  '어파이어',
#  '여덟 개의 산',
#  '너의 시선이 머무는 곳에',
#  '타겟',
#  '여름을 향한 터널, 이별의 출구',
#  '가문의 영광: 리턴즈',
#  '플로라 앤 썬',
#  '킴스 비디오',
#  '오펜하이머',
#  '더 넌 2',
#  '거미집',
#  '시아버지 저 임신 하고 싶어요',
#  '미시는 청년을 좋아해:나이가 깡패',
#  '내물건이 갖고 싶으냐 : 널 보면 회춘',
#  '낮엔 처형이랑 밤엔 여친이랑:한 이불 두 여자',
#  '검은 상복의 모녀',
#  '피닉스 미션',
#  '여사장 : 월급대신 떡',
#  '남친이 군대 간 사이',
#  '결혼을 반대한 형이 아내를 건드렸다',
#  'AS기사 유혹하는 여주인',
#  'A급 여비서',
#  '오르소',
#  '납치: 사라진 메구미',
#  '형수의 젖은 가랑이 무삭제판',
#  '은밀한곳 젖은 친구엄마 무삭제판',
#  '남자전용 미용실',
#  '그래픽 디자이어',
#  '가정교사:동정풀이 일타강사',
#  '하루 세번 새아들 세워버린 엄마',
#  '내 남편은 정자왕:1일 3발 쌉가능',
#  '남편 옆에서 옆집남자 올라탄 썰',
#  '형수:시동생 몸수발 들다 젖었어요',
#  '육욕 가정부:육체로 봉사하는 유부녀',
#  '사촌여동생:활짝 열어준 문',
#  '발기가 죽지 않아:새엄마가 먹인 비타민',
#  '색끼 흘리는 여사원들',
#  '바지 내려준 형수:가득 채워줘요',
#  '동생 몰래 잔뜩 맛본 제부의 맛',
#  '과부형수 안 깊이 넣어준 썰',
#  '80일간의 세계일주',
#  '교환부부의 세계3 ： 그들만의 은밀한 테크닉',
#  '원나잇 새엄마:여관에서 섹스어필',
#  '야설읽다 터져버린 하마사키 마오',
#  '물 가득 찬 새엄마:피도 안섞였는데 뭐',
#  '남편대신 뚫어준 배관공:시원하게 뚫어드려요',
#  '지옥갱',
#  '론 서바이버 : 아이 엠 리벤지',
#  '술집에서 몰래 하는 사이',
#  '출장 중 바람 났어 : 원하는 대로 해줄게요',
#  '자위책방：한 남자 두 여자',
#  '사먹는 세자매',
#  '닌자터틀: 뮤턴트 대소동',
#  '블랙 데몬',
#  '번개맨: 더 비기닝',
#  '회장님께 벌린 새엄마의 모성애',
#  '출장 간 남편 대신 내가 벗어줄게',
#  '새엄마 아빠에게는 비밀로 해요',
#  '발정난 밤꽃 향기 찾는 옆집 부인',
#  '발정난 녀석들：5가지 맛',
#  '커밍 홈 어게인',
#  '이터널 메모리',
#  '런닝맨: 리벤져스',
#  '말이야 바른 말이지',
#  '소울메이트',
#  '작전명씨울프',
#  '아르고 원정대: 꼬마 영웅 패티의 대모험',
#  '물안에서',
#  '잠',
#  '베니스 유령 살인사건',
#  '그란 투리스모',
#  '칸다하',
#  '더 리프: 언더 워터',
#  '노크: 더 하우스',
#  '나의 그리스식 웨딩 3',
#  '경미의 세계',
#  '힙노틱',
#  '차박- 살인과 낭만의 밤',
#  '료마! 테니스의 왕자: 디사이드',
#  '노트르담 온 파이어',
#  '책 종이 가위',
#  '아이유 콘서트 : 더 골든 아워',
#  '뮤직 샤펠',
#  '리벤지 나이트',
#  '일주일간 친구',
#  '비밀의 언덕',
#  '물꽃의 전설',
#  '새로운 시대: 악의 도시',
#  '한 남자',
#  '몸값part.2',
#  '몸값part.1',
#  '이노센트',
#  '어느 멋진 아침',
#  '생츄어리: 마법의 소원나무',
#  '극장판 사사키와 미야노 - 졸업편',
#  '206: 사라지지 않는',
#  '식운',
#  '앙드레 류: 러브 이즈 올 어라운드',
#  '라모나 ',
#  '여대생 가사도우미',
#  '경감 매그레',
#  '욕정채운 쇼핑',
#  '욕정 채운 유부녀',
#  '쉽게 열린 가랑이',
#  '삼총사',
#  '간호사는 욕정충전기',
#  '어린 처제2',
#  '모하비 다이아몬드',
#  '흠뻑 젖어버린 방 무삭제판',
#  '음란치료사의 참교육',
#  '우리동네 미용실 ： 2대1서비스',
#  'mz 자매의 목적',
#  'SAS: 레니게이드 인 런던',
#  '여상사의 노예가 되어줄게요',
#  '남편 몰래 수컷 냄새 맡으러 가요',
#  '젖 큰 가정교사와 이대일 2',
#  '잘 뚫는 배관공:다른 곳도 뚫어줘요',
#  '의붓남매:한지붕 한침대',
#  '옆집여자와 합체한 썰',
#  '새엄마:목욕 시켜줄게요',
#  '잠든 여선배 다리 사이 쫄리는 맛',
#  '임신하고픈 데카걸 아리스 잔뜩 모아 한번에 보내줘',
#  '요분질 여사원:오늘 잠 다 잤네',
#  '싱싱한 새아들 조금 맛 봐줄게',
#  '낭만여행',
#  '자지 말라는 여후배:자꾸만 조여와',
#  '이상형이 아빠와 결혼했다',
#  '단단한 새아들:너하고 밤꽃냄새 맡고싶어',
#  '나는 시아버지의 아내가 되기로 결심했다',
#  '강사녀:강간범을 사냥하는 여자',
#  '47시간: 샤크베이트',
#  '새엄마의 섹스특강',
#  '버릇없는 의붓여동생 길들이기',
#  '맞바람:밤꽃 향기 남기고 갔단다',
#  '피아노 프리즘',
#  '조이 라이드',
#  '스파이 코드명 포춘',
#  '더 도어 : 다섯 개의 문',
#  '남친 몰래 메이드 알바 주인님 원하시는 대로',
#  '그녀의 PS파트너',
#  '몬스터 패밀리 2',
#  '더 버닝 씨',
#  '99번의 정사',
#  '치치치 치킨의 비밀',
#  '마야 3: 숲속 왕국의 위기',
#  '에릭 클랩튼: 어크로스 24 나이츠',
#  '람보르기니: 전설이 된 남자',
#  '아만다',
#  '강변의 무코리타',
#  '볼코노고프 대위 탈출하다',
#  '드림팰리스',
#  '킬러의 레스토랑',
#  '레이디',
#  '사고물건 무서운 방',
#  '그 노래',
#  '교전',
#  '메가로돈 2',
#  '인시디어스: 빨간 문',
#  '아포리아',
#  '바다 탐험대 옥토넛 어보브 앤 비욘드 : 육지 넘어 하늘까지!',
#  '다섯 번째 흉추',
#  '이름 없는 춤',
#  '마에스트로',
#  '살바도르 달리 : 불멸을 찾아서',
#  '붉은 사막',
#  '한번 죽어 봤다',
#  '슈퍼 키드 헤일리',
#  '극장판 아름다운 그: 이터널',
#  '파이어하트',
#  '방탄소년단: 옛 투 컴 인 시네마',
#  '골프레슨 특별한 기술',
#  '다크 글래시스',
#  '핑크퐁 시네마 콘서트3 : 진저브레드맨을 잡아라',
#  '극장판 피노키오 위대한 모험',
#  '던전 앤 드래곤: 도적들의 명예',
#  '헌티드 맨션',
#  '에고이스트',
#  '메타모르포제의 툇마루',
#  '바비',
#  '틴에이지 크라켄 루비',
#  '샤이닝',
#  '좋.댓.구',
#  '군산전기',
#  '악마들',
#  '아버지의 마음',
#  '인드림',
#  '마마무: 마이콘 더 무비',
#  '귀공자',
#  '제이홉 인 더 박스',
#  '보 이즈 어프레이드',
#  '차선변경-큐폴라를 올려다보며-',
#  '극장판 슈퍼윙스: 맥시멈 스피드',
#  '매복',
#  '러브 라이프',
#  '그녀가 좋아하는 것은',
#  '보통의 카스미',
#  '더 썬',
#  '호쿠사이',
#  '좀비 사용 설명서',
#  '슬기로운 아내 수업',
#  '블레이즈',
#  '미션 임파서블: 데드 레코닝 PART ONE',
#  '디어 마이 러브',
#  '극장판 도라에몽: 진구와 하늘의 유토피아',
#  '2022 심규선 단독 콘서트 [밤의 정원: 앙코르]',
#  '플래닛',
#  '악마의 부활',
#  '와일드캣',
#  '엘리멘탈',
#  '낭만적 공장',
#  '우리 사랑이 향기로 남을 때',
#  '킬링 로맨스',
#  '리바운드',
#  '하얀봄',
#  '풍재기시',
#  '엔니오: 더 마에스트로',
#  '기적을 믿는 소녀',
#  '1986 그 여름, 그리고 고등어통조림',
#  '유령',
#  '너무 쉬운 며느리 무삭제판',
#  '뮤지컬 윌리엄과 윌리엄의 윌리엄들',
#  '위험한 사돈',
#  '슈가: 로드 투 디데이',
#  '실버맨',
#  '육지것들',
#  '안나푸르나',
#  '포트리스2 : 스나이퍼 아이',
#  '익스파이어드',
#  '뮤지컬 청춘소음',
#  '그 여름',
#  '인디아나 존스: 운명의 다이얼',
#  '룸 203',
#  '2022 영탁 단독 콘서트 "탁쇼"',
#  '엽문의 시작',
#  '명탐정코난: 하이바라 아이 이야기 ~흑철의 미스터리 트레인',
#  '스파이더맨: 어크로스 더 유니버스',
#  '살롱 드 서울',
#  '북 오브 러브',
#  '믿거나 말거나, 진짜야',
#  '뮤지컬 앨리스',
#  '위대한 작은 농장',
#  '너의 눈을 들여다보면',
#  '금지된 관계',
#  '부화',
#  '극장판 극주부도',
#  '문재인입니다',
#  '대외비',
#  '플래시',
#  '김재훈의 피.엔.오',
#  '비의도적 연애담 스페셜',
#  '블랙 워터: 어비스',
#  '나의 사소한 슬픔',
#  '트랜스포머: 비스트의 서막',
#  '사랑하는 당신에게',
#  '박하경 여행기',
#  '무한궤도 (가면속의 거짓말)',
#  '이윽고 바다에 닿다',
#  '북 클럽: 넥스트 챕터',
#  '부기맨',
#  '배우의 꿈',
#  '바깥 나라의 소녀',
#  '리턴 투 서울',
#  '미드나잇 스완',
#  '남자는 처음을 원하고 여자는 마지막을 원한다',
#  '포트리스: 더 벙커',
#  '13 미닛츠',
#  '타임 이즈 업2',
#  '악당들',
#  '세인트 세이야: 더 비기닝',
#  '말없는 소녀',
#  '마인드케이지',
#  '라이드 온',
#  '초대의 법칙',
#  '보이지 않아',
#  '빅트립2: 아기곰 배달 대작전',
#  '카일리 블루스',
#  '메리 마이 데드 바디',
#  '내 아내 이야기',
#  '사슴의 왕',
#  '이스케이프 더 보트',
#  '줄리아의 인생극장',
#  '인어공주',
#  '스크림6',
#  '뮤지컬 더 데빌 2021',
#  '뮤지컬 호프',
#  '페이퍼 스파이더스',
#  '극장판 리틀 슈퍼맨 샘샘',
#  '거신: 바람의 아이',
#  '플레이 뮤지컬 핑크퐁과 아기상어의 생일파티 대소동',
#  '슬픔의 삼각형',
#  '분노의 질주: 라이드 오어 다이',
#  '아머드 사우루스: 기계공룡제국의 침략',
#  '옥수역귀신',
#  '데우스',
#  '칠중주: 홍콩 이야기',
#  '유랑지구2',
#  '바람개비',
#  '가디언즈 오브 갤럭시: Volume 3',
#  '토리와 로키타',
#  '엑소시스트: 더 바티칸',
#  '뮤지컬 더 데빌 2018',
#  '차별',
#  '극장판 짱구는 못말려: 동물소환 닌자 배꼽수비대',
#  '라이스보이 슬립스',
#  '무명',
#  '뮤지컬 공연실황, 알쏭달쏭 캐치! 티니핑 <신비한 상자를 열어라!>',
#  '클로즈',
#  '그 아이는 귀족',
#  '오글리스: 웰컴 투 냄새 마을',
#  '튤립 모양',
#  '불멸의 여자',
#  '항구의 니쿠코짱!',
#  '롱 플레이스',
#  '존 윅 4',
#  '피기',
#  '자전거 도둑',
#  '슈퍼 마리오 브라더스',
#  '스마일 어게인',
#  '치킨래빗: 잃어버린 보물을 찾아서',
#  '거울 속 외딴 성',
#  '라스트 필름 쇼',
#  '캐리 러브콘서트 케이팝',
#  '살룸의 하이에나',
#  '65',
#  '콜드플레이 뮤직 오브 더 스피어스: 라이브 앳 리버 플레이트',
#  '천개의 별 이야기 더 시리즈',
#  '오디션',
#  '렌필드',
#  '귀를 기울이면',
#  '밥만 잘 사주는 이상한 이사님 극장판',
#  '하룻밤',
#  '메탈리카: 72 시즌스',
#  '나의 연인에게',
#  '장기자랑',
#  '치치핑핑의 쿵쿵따 탐험대',
#  '엘 카미노',
#  '카구야 님은 고백받고 싶어 -첫 키스는 끝나지 않아-',
#  '곰돌이 푸: 피와 꿀',
#  '에어',
#  '뮤턴트 이스케이프',
#  '사쿠라',
#  '민족 ',
#  '웅남이',
#  '서유기:저팔계의 반란',
#  '더 벙커',
#  '파벨만스',
#  '베리얼: 라스트 미션',
#  '흐르다',
#  '블라스트: 폭탄제거반',
#  '이스케이프: 더블 타겟',
#  '나의 이웃 히틀러',
#  '오토라는 남자',
#  '샷건 웨딩',
#  '블루 서멀, 같은 하늘을 보고 싶어 ',
#  '어떤 영웅',
#  '리틀 엘렌: 외계인과 안테나 대소동',
#  '콜 제인',
#  '카운트',
#  '여기도 사람 있어요',
#  '섀도우 마스터',
#  '모나리자와 블러드 문',
#  '포커페이스',
#  '꼬마돼지 베이브의 바다 대모험',
#  '팔로우드',
#  '틸',
#  '플레인',
#  '샤잠! 신들의 분노',
#  '컨버세이션',
#  '에브리씽 에브리웨어 올 앳 원스+',
#  '더 웨일',
#  '살수',
#  '6번 칸',
#  '쏜애플 불구경 2022 라이브 콘서트 필름',
#  '천룡팔부: 교봉전',
#  '애니씽 고즈: 라이브 인 런던',
#  '똑똑똑',
#  '그대 어이가리',
#  '관계의 일변',
#  '귀멸의 칼날: 상현집결, 그리고 도공 마을로',
#  '크리드 3',
#  '아임 히어로 더 파이널',
#  '루비콘',
#  '시몬',
#  '바다 탐험대 옥토넛 육지수호 대작전 : 열대우림을 지켜라!',
#  '지퍼스 크리퍼스: 리본',
#  '서치 2',
#  '미녀와 야수: 마법에 걸린 왕자',
#  'TAR 타르',
#  '열여덟, 어른이 되는 나이',
#  '시간을 꿈꾸는 소녀',
#  '어메이징 모리스',
#  '극장판 카케구루이2: 절체절명의 러시안 룰렛',
#  '스위치',
#  '스톰 보이',
#  '카메라를 멈추면 안 돼! 프랑스에서도',
#  '트윈',
#  '피터 본 칸트',
#  '앤트맨과 와스프: 퀀텀매니아',
#  '단순한 열정',
#  '궁지에 몰린 쥐는 치즈 꿈을 꾼다',
#  '원 웨이',
#  '울프 하운드',
#  '라스트 버스',
#  '안녕, 소중한 사람',
#  '성스러운 거미',
#  '디텍티브 나이트: 가면의 밤',
#  '네가 떨어뜨린 푸른 하늘',
#  '강남좀비',
#  '10일간의 애인',
#  '나는 마을 방과후 교사입니다',
#  '교섭',
#  '몬스터 하우스2: 인비져블 피닉스',
#  '극장판 전생했더니 슬라임이었던 건에 대하여: 홍련의 인연편',
#  '극장판 카케구루이',
#  '이마 베프',
#  '생각 그런거 없는데요',
#  '극장판 겁쟁이 페달',
#  'FBI: 마약전쟁',
#  '빌리 아일리시: 라이브 앳 디 오투 (확장판)',
#  '새를 사랑한 화가',
#  '울브스 오브 워',
#  '새비지 맨',
#  '견자단의 용호무사',
#  '유랑의 달',
#  '해시태그 시그네',
#  '위너 2022 콘서트 더 서클 더 무비',
#  '뮤지컬 레드북',
#  '메간',
#  '라인',
#  '돌핀보이',
#  '벤데타: 복수의 시간',
#  '극장판 파워레인저 캡틴포스: 지구를 위한 싸움',
#  '프리 데드 오어 얼라이브',
#  '3000년의 기다림',
#  '라일 라일 크로커다일',
#  '문맨',
#  '프린스 챠밍',
#  '마리앙투아네트',
#  '장화신은 고양이: 끝내주는 모험',
#  '패닉 런',
#  '처음 꽃향기를 만난 순간',
#  '뮤지컬 번지점프를 하다',
#  '뮤지컬 배니싱',
#  '트루 마더스']

# %%
year_list = movie['제작연도'].to_list()
year_list
# Out:
# ['2022',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2020',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2021',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2021',
#  '2023',
#  '2023',
#  '2004',
#  '2023',
#  '2021',
#  '2023',
#  '2021',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2021',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2021',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '0',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '0',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2020',
#  '2022',
#  '2021',
#  '2022',
#  '2022',
#  '2020',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2019',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2021',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2020',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2021',
#  '2023',
#  '2023',
#  '2022',
#  '2021',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2021',
#  '2022',
#  '2019',
#  '2023',
#  '2023',
#  '2020',
#  '2023',
#  '2022',
#  '2022',
#  '0',
#  '2021',
#  '0',
#  '2023',
#  '0',
#  '0',
#  '2020',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2019',
#  '2022',
#  '2019',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '0',
#  '2022',
#  '0',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '0',
#  '0',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2021',
#  '2022',
#  '2020',
#  '2022',
#  '2022',
#  '2020',
#  '2023',
#  '2022',
#  '2022',
#  '2019',
#  '1995',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '0',
#  '0',
#  '2023',
#  '2021',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2020',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '0',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2021',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2021',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2021',
#  '2022',
#  '2023',
#  '1990',
#  '2022',
#  '2023',
#  '2021',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2004',
#  '2021',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2021',
#  '2023',
#  '1988',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2021',
#  '2022',
#  '2021',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '0',
#  '2023',
#  '2023',
#  '0',
#  '0',
#  '0',
#  '2023',
#  '2023',
#  '2020',
#  '2022',
#  '2022',
#  '0',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '0',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '0',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2020',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2019',
#  '2023',
#  '2023',
#  '2022',
#  '2020',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2019',
#  '0',
#  '2023',
#  '2021',
#  '2022',
#  '2019',
#  '2023',
#  '2023',
#  '2022',
#  '2021',
#  '2022',
#  '2022',
#  '2021',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2022',
#  '2019',
#  '2023',
#  '2022',
#  '2020',
#  '2023',
#  '2021',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '0',
#  '2021',
#  '2021',
#  '2022',
#  '2023',
#  '2021',
#  '2023',
#  '2022',
#  '2022',
#  '2021',
#  '2021',
#  '2022',
#  '2022',
#  '2022',
#  '2020',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2021',
#  '2022',
#  '2022',
#  '1964',
#  '2020',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2021',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '1980',
#  '2023',
#  '2020',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2021',
#  '2022',
#  '2021',
#  '2022',
#  '2022',
#  '2020',
#  '2021',
#  '2020',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2021',
#  '2023',
#  '2022',
#  '2022',
#  '2021',
#  '2022',
#  '2023',
#  '2022',
#  '2021',
#  '2021',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2021',
#  '2023',
#  '2021',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2020',
#  '2023',
#  '2023',
#  '2022',
#  '2021',
#  '2022',
#  '2023',
#  '2018',
#  '2021',
#  '2022',
#  '2022',
#  '2022',
#  '2023',
#  '2020',
#  '2023',
#  '2023',
#  '2022',
#  '2020',
#  '2021',
#  '2023',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2020',
#  '2022',
#  '2021',
#  '2021',
#  '2022',
#  '2021',
#  '2023',
#  '2021',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2022',
#  '2015',
#  '2022',
#  '2021',
#  '2021',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2021',
#  '2020',
#  '2021',
#  '2022',
#  '2022',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2021',
#  '2022',
#  '2020',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2018',
#  '2021',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2021',
#  '2021',
#  '2020',
#  '2022',
#  '2021',
#  '2022',
#  '2023',
#  '2022',
#  '1948',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2023',
#  '2021',
#  '2023',
#  '2022',
#  '2021',
#  '1999',
#  '2023',
#  '2022',
#  '2023',
#  '2019',
#  '2023',
#  '2021',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2023',
#  '2023',
#  '2022',
#  '2020',
#  '2020',
#  '2023',
#  '2020',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2021',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2022',
#  '2022',
#  '2021',
#  '2023',
#  '2022',
#  '2021',
#  '2022',
#  '2022',
#  '2018',
#  '2022',
#  '2023',
#  '2023',
#  '2021',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2023',
#  '2022',
#  '2021',
#  '2023',
#  '2022',
#  '2022',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2021',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2021',
#  '2019',
#  '2022',
#  '2021',
#  '2022',
#  '2023',
#  '2020',
#  '2020',
#  '2022',
#  '2022',
#  '2021',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2019',
#  '1996',
#  '2022',
#  '2020',
#  '2022',
#  '2022',
#  '2021',
#  '2022',
#  '2022',
#  '2020',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2018',
#  '2022',
#  '2022',
#  '2021',
#  '2021',
#  '2022',
#  '2020',
#  '2020']

# %%
movie.reset_index(drop = True, inplace=True)

# %%
movie
# Out:
#                영화명                        영화명(영문)  제작연도 제작국가  유형          장르  \
# 0        남은 인생 10년              The Last 10 Years  2022   일본  장편      멜로/로맨스
# 1      달짝지근해: 7510                     HONEYSWEET  2022   한국  장편         코미디
# 2               폭로                         Havana  2022   한국  장편      범죄,스릴러
# 3     어디로 가고 싶으신가요    Where Would You Like to Go?  2023   한국  장편         드라마
# 4      만해 한용운 님의침묵                 Silence of Thy  2022   한국  장편         드라마
# ..             ...                            ...   ...  ...  ..         ...
# 770           패닉 런             The Desperate Hour  2021   미국  장편         스릴러
# 771  처음 꽃향기를 만난 순간  Fragrance of the First Flower  2021   대만  장편  드라마,멜로/로맨스
# 772   뮤지컬 번지점프를 하다                            NaN  2022   한국  장편      뮤지컬,공연
# 773        뮤지컬 배니싱                            NaN  2020   한국  장편      뮤지컬,공연
# 774         트루 마더스                   True Mothers  2020   일본  장편         드라마
#
#     제작상태        감독                  제작사
# 0     개봉  후지이 미치히토                  NaN
# 1     개봉        이한               (주)무비락
# 2     개봉       홍용호          (주)로그라인스튜디오
# 3     개봉       김희정             (주)인벤트스톤
# 4     개봉       한명구           주식회사 시네마서울
# ..   ...       ...                  ...
# 770   개봉    필립 노이스                  NaN
# 771   개봉       덩이한                  NaN
# 772   개봉       윤영호  씨제이 씨지브이(CJ CGV)(주)
# 773   개봉       이헌재  씨제이 씨지브이(CJ CGV)(주)
# 774   개봉   가와세 나오미                  NaN
#
# [775 rows x 9 columns]

# %%
### 데이터 프레임화

base_url = 'https://pedia.watcha.com/ko-KR/searches/movies?query='

movie_info = []
movie_review = []

#for i in range(len(movie_list)):
for i in range(100, 120):
    movie_title = movie['영화명'][i]
    movie_year = movie['제작연도'][i]

    url = base_url + movie_title

    driver = webdriver.Chrome()

    driver.get(url)
    driver.set_window_position(-1800,10)

    # 화면이 뜰때까지 기다리기
    driver.implicitly_wait(10)
    # 창 최대화
    # driver.maximize_window()
    # time.sleep(2.4)
    time.sleep(round(random.uniform(1.3, 2.2), 3))

    #################################################################################################################
    ### 같은 제목의 영화에서 제작연도가 같은 영화를 선택
    same_lis = driver.find_element(By.CLASS_NAME, 'e1493pgd7').find_elements(By.CLASS_NAME, 'e1ic68ft1')

    cnt = 0
    for li in same_lis:
        li.find_element(By.CLASS_NAME, 'e1gexyxq5').text.strip().split(' ・')[0]
        if li.find_element(By.CLASS_NAME, 'e1gexyxq5').text.strip().split(' ・')[0] != movie_year:
            cnt += 1
        else :
            print(li.find_element(By.CLASS_NAME, 'e1gexyxq4').text.strip())
            print(cnt)
            break

    # 제작연도가 같은 영화가 없을 경우에 첫번째 영화를 선택
    try:
        same_lis[cnt].click()
    except:
        same_lis[0].click()

    #################################################################################################################
    ### 영화 정보 크롤링
    # 영화 소개
    summary = driver.find_element(By.CLASS_NAME, 'e1yew2864').text.strip().replace('\n', '')

    # 감독/출연진
    actor_list = []
    person_lis = driver.find_element(By.CLASS_NAME, 'e1n40jsk1').find_elements(By.CLASS_NAME, 'e4f2vpe2')
    for person in person_lis:
        actor_list.append(person.find_element(By.TAG_NAME, 'a').get_attribute('title'))

    # 전체 평점
    total_rating = driver.find_element(By.CLASS_NAME, 'e15eo6m110').text

    # 전체 평점 리뷰어수
    rating_cnt = driver.find_element(By.CLASS_NAME, 'e15eo6m19').text.split('\n')[-1]
    

    # 정보 1
    info1 = driver.find_element(By.CLASS_NAME, 'e1yew28613').find_elements(By.CLASS_NAME, 'e1yew28611')[1].text

    # 정보 2
    info2 = driver.find_element(By.CLASS_NAME, 'e1yew28613').find_elements(By.CLASS_NAME, 'e1yew28611')[2].text

    time.sleep(round(random.uniform(1.3, 2.2), 3))
    movie_info.append({'title' : movie_title,
                       'movie_num' : i,
                       'summary' : summary,
                       'actor_list': actor_list,
                       'rating' : total_rating,
                       'rating_cnt' : rating_cnt,
                       'info1' : info1,
                       'info2' : info2})
    
    #################################################################################################################
    # 리뷰 페이지 이동
    driver.find_element(By.CLASS_NAME, 'ehapiph0').click()
    time.sleep(round(random.uniform(1.3, 2.2), 3))

    # 스크롤 다운
    for _ in range(5):
        last_height = driver.execute_script("return document.body.scrollHeight")

        # 창의 내리기 끝까지 하지않고, 중간에 멈춰서 한번은 page_down을 통해서
        driver.execute_script(f'window.scrollTo(0, {last_height - random.randint(1, 100)})')
        time.sleep(round(random.uniform(1.0, 1.5), 3))
        driver.find_element(By.TAG_NAME, 'body').send_keys(Keys.PAGE_DOWN)     
        time.sleep(round(random.uniform(0.3, 1.2), 3))
    time.sleep(round(random.uniform(1.3, 2.2), 3))

    num = 0
    review_list = driver.find_elements(By.CLASS_NAME, 'egj9y8a4')
    for review_li in review_list:
        
        # 평점이 없는 경우 발생 - ex)보고싶어요
        try:
            # 평점
            review_rating = review_li.find_element(By.CLASS_NAME, 'egj9y8a0').text.strip()

            #사용자명
            reviewer = review_li.find_element(By.CLASS_NAME, 'e10cf2lr1').text.strip()

            # 리뷰
            review = review_li.find_element(By.CLASS_NAME, 'e1hvy88212').text.strip().replace('\n', '')

            # num
            num += 1

            movie_review.append({'title' : movie_title,
                                 'movie_num' : i,
                                 'review_num' : num,
                                 'reviewer' : reviewer,
                                 'review_rating' : review_rating,
                                 'review' : review})
        except:
            continue
    time.sleep(round(random.uniform(1.3, 2.2), 3))

    driver.close()
# Out:
# 힐마 아프 클린트 - 미래를 위한 그림
# 0
# 트롤: 밴드 투게더
# 0
# 아쿠아맨과 로스트 킹덤
# 0
# 세계를 뒤흔든 43일
# 0
# 제시는 그때 스무살이었다
# 0
# 매트
# 0
# 매드 하이디
# 0
# 라스트 서바이버
# 0
# 약속
# 1
# 조이랜드
# 0
# 인디펜던스 나이트
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 15
#      11 movie_year = movie['제작연도'][i]
#      13 url = base_url + movie_title
# ---> 15 driver = webdriver.Chrome()
#      17 driver.get(url)
#      18 driver.set_window_position(-1800,10)
#
# File c:\Users\tjoeun\miniconda3\envs\project2\lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File c:\Users\tjoeun\miniconda3\envs\project2\lib\site-packages\selenium\webdriver\chromium\webdriver.py:61, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      52 executor = ChromiumRemoteConnection(
#      53     remote_server_addr=self.service.service_url,
#      54     browser_name=browser_name,
#    (...)
#      57     ignore_proxy=options._ignore_local_proxy,
#      58 )
#      60 try:
# ---> 61     super().__init__(command_executor=executor, options=options)
#      62 except Exception:
#      63     self.quit()
#
# File c:\Users\tjoeun\miniconda3\envs\project2\lib\site-packages\selenium\webdriver\remote\webdriver.py:208, in WebDriver.__init__(self, command_executor, keep_alive, file_detector, options)
#     206 self._authenticator_id = None
#     207 self.start_client()
# --> 208 self.start_session(capabilities)
#
# File c:\Users\tjoeun\miniconda3\envs\project2\lib\site-packages\selenium\webdriver\remote\webdriver.py:292, in WebDriver.start_session(self, capabilities)
#     285 """Creates a new session with the desired capabilities.
#     286
#     287 :Args:
#     288  - capabilities - a capabilities dict to start the session with.
#     289 """
#     291 caps = _create_caps(capabilities)
# --> 292 response = self.execute(Command.NEW_SESSION, caps)["value"]
#     293 self.session_id = response.get("sessionId")
#     294 self.caps = response.get("capabilities")
#
# File c:\Users\tjoeun\miniconda3\envs\project2\lib\site-packages\selenium\webdriver\remote\webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     342     elif "sessionId" not in params:
#     343         params["sessionId"] = self.session_id
# --> 345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
#     347     self.error_handler.check_response(response)
#
# File c:\Users\tjoeun\miniconda3\envs\project2\lib\site-packages\selenium\webdriver\remote\remote_connection.py:302, in RemoteConnection.execute(self, command, params)
#     300 trimmed = self._trim_large_entries(params)
#     301 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 302 return self._request(command_info[0], url, body=data)
#
# File c:\Users\tjoeun\miniconda3\envs\project2\lib\site-packages\selenium\webdriver\remote\remote_connection.py:322, in RemoteConnection._request(self, method, url, body)
#     319     body = None
#     321 if self.keep_alive:
# --> 322     response = self._conn.request(method, url, body=body, headers=headers)
#     323     statuscode = response.status
#     324 else:
#
# File c:\Users\tjoeun\miniconda3\envs\project2\lib\site-packages\urllib3\_request_methods.py:144, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     136     return self.request_encode_url(
#     137         method,
#     138         url,
#    (...)
#     141         **urlopen_kw,
#     142     )
#     143 else:
# --> 144     return self.request_encode_body(
#     145         method, url, fields=fields, headers=headers, **urlopen_kw
#     146     )
#
# File c:\Users\tjoeun\miniconda3\envs\project2\lib\site-packages\urllib3\_request_methods.py:279, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     275     extra_kw["headers"].setdefault("Content-Type", content_type)
#     277 extra_kw.update(urlopen_kw)
# --> 279 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\tjoeun\miniconda3\envs\project2\lib\site-packages\urllib3\poolmanager.py:444, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     442     response = conn.urlopen(method, url, **kw)
#     443 else:
# --> 444     response = conn.urlopen(method, u.request_uri, **kw)
#     446 redirect_location = redirect and response.get_redirect_location()
#     447 if not redirect_location:
#
# File c:\Users\tjoeun\miniconda3\envs\project2\lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File c:\Users\tjoeun\miniconda3\envs\project2\lib\site-packages\urllib3\connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\tjoeun\miniconda3\envs\project2\lib\site-packages\urllib3\connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\tjoeun\miniconda3\envs\project2\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File c:\Users\tjoeun\miniconda3\envs\project2\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File c:\Users\tjoeun\miniconda3\envs\project2\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File c:\Users\tjoeun\miniconda3\envs\project2\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# Out:
# 0           남은 인생 10년
# 1         달짝지근해: 7510
# 2                  폭로
# 3        어디로 가고 싶으신가요
# 4         만해 한용운 님의침묵
#             ...
# 1542             패닉 런
# 1543    처음 꽃향기를 만난 순간
# 1544     뮤지컬 번지점프를 하다
# 1545          뮤지컬 배니싱
# 1546           트루 마더스
# Name: 영화명, Length: 775, dtype: object

# %%
df_info = pd.DataFrame(movie_info)
df_review = pd.DataFrame(movie_review)
# Out:
#                     title  movie_num  \
# 0   힐마 아프 클린트 - 미래를 위한 그림        100
# 1              트롤: 밴드 투게더        101
# 2            아쿠아맨과 로스트 킹덤        102
# 3                      화란        103
# 4             세계를 뒤흔든 43일        104
# 5           제시는 그때 스무살이었다        105
# 6                      매트        106
# 7                  매드 하이디        107
# 8                라스트 서바이버        108
# 9                      약속        109
# 10                   조이랜드        110
# 11              인디펜던스 나이트        111
#
#                                               summary  \
# 0   ”내가 죽은 후 20년 동안 내 작품을 공개하지 말라”는 유언을 남긴 세계 최초의 ...
# 1   최애 아이돌 그룹 재결합 초읽기! 우리 함께하면 더 좋잖아! \n\n전 세계 모든 ...
# 2   아틀란티스 왕국을 이끌 왕의 자리에 오른 ‘아쿠아맨’. 그 앞에 ‘블랙 만타’가 세...
# 3   지옥 같은 현실에서 벗어나고 싶은 소년 '연규'가 조직의 중간 보스 ‘치건’을 만나...
# 4   부처님의 행적을 따라서 상월결사 회주 자승 스님을 중심으로 한 인도순례단의 걸음 1...
# 5   가난한 어부촌의 벙어리로 태어나,학교도 한번 못가보고 제대로 된 글 한번 깨우쳐보지...
# 6   매트에 오르면, 심판이 시작된다! \n\n어느날 갑자기 매트 위로 불려온 여덟 명의...
# 7   사악한 독재자가 통치하는 디스토피아의 스위스. 알프스 소녀 ‘하이디’는 할아버지와 ...
# 8   인류의 마지막 대전쟁 그 이후, 아버지 ‘트로이’와 아들 ‘제이크’는 20년 동안 ...
# 9   엄마와 이별한 아홉 살 ‘시우’는 아빠와 약속한다. \n“1년 뒤에 엄마가 있는 곳...
# 10  몇 년째 전업주부로 살던 하이더르는 카리스마 있는 트랜스젠더 뮤지션 비바의 백댄서로...
# 11  더 이상의 테러는 없다!  \n\n경찰의 꿈이 좌절된 후 구급대원으로 일하는 ‘데지...
#
#                                            actor_list rating rating_cnt  \
# 0   [할리나 디르슈카(감독), 힐마 아프 클린트(출연 | 본인), 에른스트 페터 피셔(...    3.6     (171명)
# 1   [월트 돈(감독), 팀 하이츠(감독), 안나 켄드릭(성우), 저스틴 팀버레이크(성우...    3.2   (1,217명)
# 2   [제임스 완(감독), 제이슨 모모아(주연 | 아서 커리/아쿠아맨), 패트릭 윌슨(조...    2.8   (7,634명)
# 3   [김창훈(감독), 홍사빈(주연 | 연규), 송중기(주연 | 치건), 비비(조연 | ...    3.0   (6,154명)
# 4                                           [이규철(감독)]    3.1      (15명)
# 5   [한명구(감독), 설향(주연 | 제시(금옥)), 임영서(주연 | 브라운 소령), 홍...    1.7      (40명)
# 6   [최지온(감독), 최지온(주연), 하지인(주연), 김장수(주연), 송성사(주연), ...    2.8      (25명)
# 7   [요하네스 하트만(감독), 앨리스 루시(주연 | 하이디), 맥스 루드링어(주연), ...    2.2      (31명)
# 8   [드류 마일레아(감독), 알리시아 실버스톤(주연 | 헨리에타), 드류 밴 아커(주연...    3.8      (15명)
# 9   [민병훈(감독), 민병훈(출연 | 본인), 민시우(출연 | 본인), 안은미(출연 |...    3.4     (123명)
# 10  [사임 사디크(감독), 알리 준조(주연), 라스티 파루프(주연), 알리나 칸(주연)...    3.7     (930명)
# 11  [에드워드 드레이크(감독), 브루스 윌리스(주연 | 제임스 나이트), 로슬린 먼로(...    1.3      (28명)
#
#                                     info1          info2
# 0   2019 · 다큐멘터리/전기/역사 · 독일, 스웨덴, 스위스, 영국   1시간 34분 · 전체
# 1             2023 · 애니메이션/키즈/모험/코미디 · 미국   1시간 32분 · 전체
# 2                       2023 · SF/액션 · 미국   2시간 4분 · 12세
# 3               2023 · 범죄/드라마/스릴러/액션 · 한국  2시간 13분 · 15세
# 4                       2023 · 다큐멘터리 · 한국   1시간 21분 · 전체
# 5                         2022 · 드라마 · 한국   2시간 27분 · 청불
# 6                    2023 · 미스터리/스릴러 · 한국  2시간 34분 · 12세
# 7           2022 · 액션/모험/코미디/판타지/공포 · 스위스   1시간 32분 · 청불
# 8                       2021 · SF/액션 · 미국  1시간 38분 · 15세
# 9                    2023 · 다큐멘터리/가족 · 한국   1시간 23분 · 전체
# 10               2022 · 가족/로맨스/드라마 · 파키스탄   2시간 6분 · 15세
# 11                      2023 · 범죄/액션 · 미국  1시간 31분 · 15세

# %%
df_info.to_csv('movie_info.csv', index = False)
df_review.to_csv('movie_review.csv', index = False)

# %%
# Out:
#          title  review_num     reviewer  \
# 0    남은 인생 10년           1           재원
# 1    남은 인생 10년           2  박준영 (영화 담다)
# 2    남은 인생 10년           3      오늘은너에게로
# 3    남은 인생 10년           4          뭅먼트
# 4    남은 인생 10년           5           JY
# ..         ...         ...          ...
# 505     3일의 휴가          93   Jamongsoda
# 506     3일의 휴가          94          심우영
# 507     3일의 휴가          95        밀크쉐이크
# 508     3일의 휴가          96          박준형
# 509     3일의 휴가          97         허허녀석
#
#                                                 review
# 0    영화를 보며 눈시울이 붉어졌던 건, 내게도 한땐내가 좀 더 괜찮은 인간이 되고 싶게...
# 1    영롱하고 유려한 피아노와 현악 음악이 흐르고 자연광과 아름다운 풍광이 서두부터 마음...
# 2                       정해진 운명은 야속했지만, 둘의 추억만큼은 행복했기를.
# 3    누군가를 살아내게 만드는 것은, 눈앞에서 점점 흐려지는 커다란 희망이 아니라 눈앞에...
# 4          부슬부슬 봄비처럼 흩날리면 뭐하나결국 2시간동안 내리면흥건해지는건 매한가지인데
# ..                                                 ...
# 505  졸았다.. 스팸김치찌개만 생각남..노스페이스, 커피, 소주, 맥주, 스팸, 맛소금…...
# 506  치유의 대상은 판타지가 아니라 현실이 되어야 한다. 현실을 치유하지 못하는 판타지는...
# 507                30분짜리 단편이로 뽑을 소재를 1시간 40분으로 늘려놓은 느낌
# 508  뻔한 이야기에, 더 뻔한 연출을김해숙, 신민아 두 배우가 살려낸다.엄마와의 <리틀 ...
# 509                    어머니의 희생과 딸의 죄책감,,, 이제 그만했으면 좋겠다
#
# [510 rows x 4 columns]
