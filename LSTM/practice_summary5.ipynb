# %% [markdown]
# https://real-myeong.tistory.com/46

# %%
from google.colab import drive
drive.mount('/content/drive')

base_path = '/content/drive/MyDrive/new_project/project2'
traindata_path = '/content/drive/MyDrive/new_project/project2/traindata/문서요약 텍스트/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
import nltk
nltk.download('stopwords')

import numpy as np
import pandas as pd
import os
import re
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import urllib.request
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='bs4')


import urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/sunnysai12345/News_Summary/master/news_summary_more.csv", filename="news_summary_more.csv")
data = pd.read_csv('news_summary_more.csv', encoding='iso-8859-1')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# 중복치 확인
print('전체 headline 데이터', len(data['headlines']))
print('유니크한 headline 데이터: ', (data['headlines'].nunique()))
print('전체 text 데이터', len(data['text']))
print('유니크한 text데이터', data['text'].nunique())
# Out:
# 전체 headline 데이터 98401
# 유니크한 headline 데이터:  98280
# 전체 text 데이터 98401
# 유니크한 text데이터 98360

# %%
data.drop_duplicates(subset=['text'], inplace=True)

# %%
data.isnull().sum()
# Out:
# headlines    0
# text         0
# dtype: int64

# %%
# 불용어 리스트 확인
print('불용어 개수 : ', len(stopwords.words('english')))
print(stopwords.words('english'))
# Out:
# 불용어 개수 :  179
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# 정규화 사전
contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}
# 불용어 리스트 확인
print('불용어 개수 : ', len(stopwords.words('english')))
print(stopwords.words('english'))
# Out:
# 불용어 개수 :  179
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
from collections import Counter
def preprocess_sentence(sentence, remove_stopwords=True):
  sentence = sentence.lower()
  sentence = BeautifulSoup(sentence, 'lxml').text # remove html tag
  sentence = re.sub(r'\([^)]*\)', '', sentence) # 괄호로 닫힌 문자열 제거
  sentence = re.sub('"', '', sentence)
  sentence = ' '.join([contractions[t] if t in contractions else t for t in sentence.split(" ")])
  sentence = re.sub(r"'s\b", "", sentence)
  sentence = re.sub("[^a-zA-Z0-9]", " ", sentence)

  # 단어 내에 같은 문자들이 3개 이상 연속해서 반복되면 삭제하고 최대 2개까지만 반복되도록 만들어줌 (ex. iiit -> iit)
  b = []
  for i in sentence.split():
    a = list(i)
    char_cnt = 0
    for j in a:
      if a.count(j) >= 3:
        a.remove(j)
    word_a = ''.join(a)
    b.append(word_a)
  sentence = ' '.join(b)


  # 불용어 제거
  if remove_stopwords:
    tokens = ' '.join(word for word in sentence.split() if not word in stopwords.words('english') if len(word) > 1)

  # 불용어 미제거
  else:
    tokens = ' '.join(word for word in sentence.split() if len(word) > 1)
  return tokens
# 샘플 문장을 확인

temp_text = 'Everything I bought was great, infact I ordered iiiiit twice and the third ordered 123 was<br />for my mother and father. '
temp_summary = 'Great way to start (or finish) the day!!!'

print("text: ", preprocess_sentence(temp_text))
print("summary:", preprocess_sentence(temp_summary, False))  # 불용어를 제거하지 않습니다.
# Out:
# text:  everything bought great infact ordered iit twice third ordered 123 wasfor mother father
# summary: great way to start the day

# %%
# data['text'] 부분 전처리 진행

clean_text = []
for s in data['text']:
  clean_text.append(preprocess_sentence(s))

print('Text 전처리 후 결과 : ', clean_text[:5])
# Out:
# Text 전처리 후 결과 :  ['saurav kant alumnus upgrad iit pg program machine learning artficial intlligence sr ystems ngineer infosys almost years work xprience program upgrad 360 dgree career support helped transition data scientist tech mahindra 90 salary hike upgrad online power learning powered lakh careers', 'kunal shah credit card bill payment platform cred gave users chance win free food swiggy one year pranav kaushik delhi techie bagged reward spending 200 cred coins users get one cred coin per rupee bill paid used avail rewards brands like ixigo bokmyshow ubereats cult fit', 'new zealand dfeated india wickets fourth odi hamilton thursday win first match five match odi series india lost iternational match rohit sharma captaincy 12 consecutive victories dating back march 2018 match witnessed india getting 92 seventh lowest total odi cricket history', 'aegon life iterm insurance plan customers enjoy tax benefits premiums paid save 46 800 taxes plan provides life cover age 100 years also customers options insure critical illneses dsability accidental death benefit rider life cover age 80 years', 'speaking sexual harassment allegations rajkumar hirani sonam kapoor said known hirani many years true metoo movement get derailed metoo movement always blieve woman case need rserve judgment aded hirani accused asistant worked sanju']

# %%
# headline 부분 전처리 진행
clean_headlines = []
for s in data['headlines']:
  clean_headlines.append(preprocess_sentence(s, False))

print('Headlines 전처리 후 결과 : ', clean_headlines[:5])
# Out:
# <ipython-input-9-38fe2475afb8>:4: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   sentence = BeautifulSoup(sentence, 'lxml').text # remove html tag
# Headlines 전처리 후 결과 :  ['upgrad learner switches to career in ml al with 90 salary hike', 'delhi techie wins free food from swiggy for one year on cred', 'new zealand end rohit sharma led india 12 match wining streak', 'aegon life iterm insurance plan helps customers save tax', 'have known hirani for yrs what if metoo claims are not true sonam']

# %%
data['text'] = clean_text
data['headlines'] = clean_headlines

data.replace('', np.nan, inplace=True)

data.isnull().sum()
# Out:
# headlines    0
# text         0
# dtype: int64

# %%
import matplotlib.pyplot as plt

text_len = [len(x.split()) for x in data['text']]
headlines_len = [len(x.split()) for x in data['headlines']]

print('텍스트 길이 최대: ', np.max(text_len))
print('텍스트 길이 최소: ', np.min(text_len))
print('텍스트 길이 평균: ', np.mean(text_len))
print('헤드라인 길이 최대: ', np.max(headlines_len))
print('헤드라인 길이 최소: ', np.min(headlines_len))
print('헤드라인 길이 평균: ', np.mean(headlines_len))
# Out:
# 텍스트 길이 최대:  60
# 텍스트 길이 최소:  1
# 텍스트 길이 평균:  36.42161447742985
# 헤드라인 길이 최대:  16
# 헤드라인 길이 최소:  1
# 헤드라인 길이 평균:  9.569611630744205

# %%
# 텍스트, 헤드라인 최대 길이 설정
max_text_len = 60
max_headline_len = 16

# 최대 길이를 기준으로 나눴을때 최대 길이보다 짧은 데이터의 비율을 출력해주는 함수 정의
def below_threshold_len(max_len, list):
  count = 0
  for s in list:
    if len(s.split()) <= max_len:
      count += 1

  print(f'길이가 {max_len}보다 짧은 데이터의 비율 : {count/len(list)}')


# 비율 확인
below_threshold_len(max_text_len, data['text'])
below_threshold_len(max_headline_len, data['headlines'])
# Out:
# 길이가 60보다 짧은 데이터의 비율 : 1.0
# 길이가 16보다 짧은 데이터의 비율 : 1.0

# %%
data['decoder_input'] = data['headlines'].apply(lambda x : 'starttoken ' + x)
data['decoder_output'] = data['headlines'].apply(lambda x : x + ' endtoken')

data.head()
# Out:
#                                            headlines  \
# 0  upgrad learner switches to career in ml al wit...
# 1  delhi techie wins free food from swiggy for on...
# 2  new zealand end rohit sharma led india 12 matc...
# 3  aegon life iterm insurance plan helps customer...
# 4  have known hirani for yrs what if metoo claims...
#
#                                                 text  \
# 0  saurav kant alumnus upgrad iit pg program mach...
# 1  kunal shah credit card bill payment platform c...
# 2  new zealand dfeated india wickets fourth odi h...
# 3  aegon life iterm insurance plan customers enjo...
# 4  speaking sexual harassment allegations rajkuma...
#
#                                        decoder_input  \
# 0  starttoken upgrad learner switches to career i...
# 1  starttoken delhi techie wins free food from sw...
# 2  starttoken new zealand end rohit sharma led in...
# 3  starttoken aegon life iterm insurance plan hel...
# 4  starttoken have known hirani for yrs what if m...
#
#                                       decoder_output
# 0  upgrad learner switches to career in ml al wit...
# 1  delhi techie wins free food from swiggy for on...
# 2  new zealand end rohit sharma led india 12 matc...
# 3  aegon life iterm insurance plan helps customer...
# 4  have known hirani for yrs what if metoo claims...

# %%
encoder_input = np.array(data['text'])

decoder_input = np.array(data['decoder_input'])
decoder_output = np.array(data['decoder_output'])

# 데이터 섞어주기
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)

encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_output = decoder_output[indices]

# 샘플 추출
encoder_input[:5]
# Out:
# array(['real madrid player marcelo admitted tax fraud accepted four month suspended jail sntence spain 30 year old brazilian paying fine 750 00 reportedly efrauded spanish authorities 490 00 several footballers accused tax fraud spain including argentina lionel messi brazil neymar jr portugal cristiano ronaldo',
#        'least 72 people penalised lakh fine collected nashik first day plastic ban came effect across mhrashtra today plastic items 350 kilograms also seized per nashik municipal crporation rlease fine first time second time offenders 00 10 00 rspectively',
#        'two muslim women took part hawan organised india hindu mhsabha aligarh friday drive practice triple talaq women claimed divorced husband using triple talaq practice women family members also according reports',
#        'authorities planing build km long 10 storey high skyscraper bridge mid 022 connect worli sewri mumbai five agencies involved planing execution project cost around 500 crore project nitially planned 2011 made headway',
#        'private lender axis bank friday said completed acqusition mobile wallet firm frecharge appointed sangram singh ceo bank completed acqusition frecharge cash consideration 373 27 crore cash free debt free basis frecharge presently rvenue 80 crore'],
#       dtype=object)

# %%
val_size = int(encoder_input.shape[0] * 0.2)

encoder_input_train = encoder_input[:-val_size]
decoder_input_train = decoder_input[:-val_size]
decoder_output_train = decoder_output[:-val_size]

encoder_input_test = encoder_input[-val_size:]
decoder_input_test = decoder_input[-val_size:]
decoder_output_test = decoder_output[-val_size:]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 78688
# 훈련 레이블의 개수 : 78688
# 테스트 데이터의 개수 : 19672
# 테스트 레이블의 개수 : 19672

# %%
# 토크나이저 설정
src_tokenizer = Tokenizer()
src_tokenizer.fit_on_texts(encoder_input_train)

# 단어 빈도수 체크
threshold = 4
total_cnt = len(src_tokenizer.word_index)
rare_cnt = 0
total_freq = 0
rare_freq = 0

for key, value in src_tokenizer.word_counts.items():
  total_freq = total_freq + value

  if value < threshold:
    rare_cnt += 1
    rare_freq = rare_freq + value


print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 71902
# 등장 빈도가 3번 이하인 희귀 단어의 수: 41062
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 30840
# 단어 집합에서 희귀 단어의 비율: 57.1082862785458
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 2.161975239369396

# %%
src_vocab = 30847
src_tokenizer = Tokenizer(num_words = src_vocab)
src_tokenizer.fit_on_texts(encoder_input_train)

# 정수 인코딩
# 텍스트 시퀀스를 정수 시퀀스로 변환
encoder_input_train = src_tokenizer.texts_to_sequences(encoder_input_train)
encoder_input_test = src_tokenizer.texts_to_sequences(encoder_input_test)

# 샘플 출력하여 확인
print(encoder_input_train[:3])
# Out:
# [[454, 1403, 336, 12565, 706, 285, 1054, 2068, 85, 139, 666, 529, 1716, 1957, 157, 3, 13, 2948, 1879, 952, 5555, 25, 24, 11619, 2117, 333, 14249, 25, 165, 6897, 44, 285, 1054, 1957, 79, 2777, 2560, 1650, 2365, 3878, 3921, 4022, 1904, 1180], [183, 2318, 10, 8792, 64, 952, 1998, 8793, 7, 45, 1423, 434, 243, 1582, 258, 367, 315, 1423, 1738, 3243, 4428, 6, 1113, 137, 8793, 1306, 846, 231, 952, 7, 27, 95, 27, 4491, 25, 51, 25, 1409], [12, 659, 53, 77, 112, 1447, 2, 789, 10589, 4962, 60, 1429, 1672, 1704, 2069, 53, 42, 5556, 421, 162, 1704, 2069, 1672, 53, 113, 277, 6, 56, 32]]

# %%
tar_tokenizer = Tokenizer()
tar_tokenizer.fit_on_texts(decoder_input_train)


threshold = 4
total_cnt = len(tar_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tar_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 31751
# 등장 빈도가 3번 이하인 희귀 단어의 수: 18120
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 13631
# 단어 집합에서 희귀 단어의 비율: 57.0690686907499
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 3.289558318395004

# %%
tar_vocab = 13676
tar_tokenizer = Tokenizer(num_words=tar_vocab)
tar_tokenizer.fit_on_texts(decoder_input_train)
tar_tokenizer.fit_on_texts(decoder_output_train)

# 텍스트 시퀀스를 정수 시퀀스로 변환
decoder_input_train = tar_tokenizer.texts_to_sequences(decoder_input_train)
decoder_target_train = tar_tokenizer.texts_to_sequences(decoder_output_train)
decoder_input_test = tar_tokenizer.texts_to_sequences(decoder_input_test)
decoder_target_test = tar_tokenizer.texts_to_sequences(decoder_output_test)

# 잘 변환되었는지 확인
print('input')
print('input ',decoder_input_train[:5])
print('target')
print('decoder ',decoder_target_train[:5])
# Out:
# input
# input  [[1, 537, 1210, 148, 2820, 432, 235, 1871, 5, 337, 489], [1, 71, 823, 4853, 4, 9101, 7, 41, 53, 6, 1115, 145], [1, 184, 514, 68, 173, 524, 4, 43, 730, 888], [1, 55, 3, 70, 7081, 1120, 6714, 13633, 3], [1, 3297, 132, 1410, 232, 16, 5595, 69]]
# target
# decoder  [[537, 1210, 148, 2820, 432, 235, 1871, 5, 337, 489, 2], [71, 823, 4853, 4, 9101, 7, 41, 53, 6, 1115, 145, 2], [184, 514, 68, 173, 524, 4, 43, 730, 888, 2], [55, 3, 70, 7081, 1120, 6714, 13633, 3, 2], [3297, 132, 1410, 232, 16, 5595, 69, 2]]

# %%
drop_train = [index for index, sentence in enumerate(decoder_input_train) if len(sentence) == 1]
drop_test = [index for index, sentence in enumerate(decoder_input_test) if len(sentence) == 1]

print('삭제할 훈련 데이터의 개수 :', len(drop_train))
print('삭제할 테스트 데이터의 개수 :', len(drop_test))

encoder_input_train = [sentence for index, sentence in enumerate(encoder_input_train) if index not in drop_train]
decoder_input_train = [sentence for index, sentence in enumerate(decoder_input_train) if index not in drop_train]
decoder_target_train = [sentence for index, sentence in enumerate(decoder_target_train) if index not in drop_train]

encoder_input_test = [sentence for index, sentence in enumerate(encoder_input_test) if index not in drop_test]
decoder_input_test = [sentence for index, sentence in enumerate(decoder_input_test) if index not in drop_test]
decoder_target_test = [sentence for index, sentence in enumerate(decoder_target_test) if index not in drop_test]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 삭제할 훈련 데이터의 개수 : 0
# 삭제할 테스트 데이터의 개수 : 0
# 훈련 데이터의 개수 : 78688
# 훈련 레이블의 개수 : 78688
# 테스트 데이터의 개수 : 19672
# 테스트 레이블의 개수 : 19672

# %%
encoder_input_train = pad_sequences(encoder_input_train, maxlen=max_text_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen=max_text_len, padding='post')
decoder_input_train = pad_sequences(decoder_input_train, maxlen=max_headline_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen=max_headline_len, padding='post')
decoder_input_test = pad_sequences(decoder_input_test, maxlen=max_headline_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen=max_headline_len, padding='post')

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(max_text_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# 디코더
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
decoder_lstm = LSTM(hidden_size, return_sequences = True, return_state = True, dropout = 0.4)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state = [state_h, state_c])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation = 'softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_outputs)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 60)]                 0         []
#
#  embedding (Embedding)       (None, 60, 128)              3948416   ['input_1[0][0]']
#
#  lstm (LSTM)                 [(None, 60, 256),            394240    ['embedding[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  input_2 (InputLayer)        [(None, None)]               0         []
#
#  lstm_1 (LSTM)               [(None, 60, 256),            525312    ['lstm[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  embedding_1 (Embedding)     (None, None, 128)            1750528   ['input_2[0][0]']
#
#  lstm_2 (LSTM)               [(None, 60, 256),            525312    ['lstm_1[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  lstm_3 (LSTM)               [(None, None, 256),          394240    ['embedding_1[0][0]',
#                               (None, 256),                           'lstm_2[0][1]',
#                               (None, 256)]                           'lstm_2[0][2]']
#
#  dense (Dense)               (None, None, 13676)          3514732   ['lstm_3[0][0]']
#
# ==================================================================================================
# Total params: 11052780 (42.16 MB)
# Trainable params: 11052780 (42.16 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
import os
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K


class AttentionLayer(Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
     """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                   shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                   shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                   shape=tf.TensorShape((input_shape[0][2], 1)),
                                   initializer='uniform',
                                   trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs, verbose=False):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs
        if verbose:
            print('encoder_out_seq>', encoder_out_seq.shape)
            print('decoder_out_seq>', decoder_out_seq.shape)

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state
            inputs: (batchsize * 1 * de_in_dim)
            states: (batchsize * 1 * de_latent_dim)
            """

            assert_msg = "States must be an iterable. Got {} of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            """ Some parameters required for shaping tensors"""
            en_seq_len, en_hidden = encoder_out_seq.shape[1], encoder_out_seq.shape[2]
            de_hidden = inputs.shape[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch size * en_seq_len * latent_dim
            W_a_dot_s = K.dot(encoder_out_seq, self.W_a)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim
            if verbose:
                print('Ua.h>', U_a_dot_h.shape)

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            Ws_plus_Uh = K.tanh(W_a_dot_s + U_a_dot_h)
            if verbose:
                print('Ws+Uh>', Ws_plus_Uh.shape)

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.squeeze(K.dot(Ws_plus_Uh, self.V_a), axis=-1)
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            if verbose:
                print('ei>', e_i.shape)

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """

            assert_msg = "States must be an iterable. Got {} of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            # <= batch_size, hidden_size
            c_i = K.sum(encoder_out_seq * K.expand_dims(inputs, -1), axis=1)
            if verbose:
                print('ci>', c_i.shape)
            return c_i, [c_i]

        fake_state_c = K.sum(encoder_out_seq, axis=1)
        fake_state_e = K.sum(encoder_out_seq, axis=2)  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e],
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c],
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

# %%
# 어텐션 층(어텐션 함수)
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis = -1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 60)]                 0         []
#
#  embedding (Embedding)       (None, 60, 128)              3948416   ['input_1[0][0]']
#
#  lstm (LSTM)                 [(None, 60, 256),            394240    ['embedding[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  input_2 (InputLayer)        [(None, None)]               0         []
#
#  lstm_1 (LSTM)               [(None, 60, 256),            525312    ['lstm[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  embedding_1 (Embedding)     (None, None, 128)            1750528   ['input_2[0][0]']
#
#  lstm_2 (LSTM)               [(None, 60, 256),            525312    ['lstm_1[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  lstm_3 (LSTM)               [(None, None, 256),          394240    ['embedding_1[0][0]',
#                               (None, 256),                           'lstm_2[0][1]',
#                               (None, 256)]                           'lstm_2[0][2]']
#
#  attention_layer (Attention  ((None, None, 256),          131328    ['lstm_2[0][0]',
#  Layer)                       (None, None, 60))                      'lstm_3[0][0]']
#
#  concat_layer (Concatenate)  (None, None, 512)            0         ['lstm_3[0][0]',
#                                                                      'attention_layer[0][0]']
#
#  dense_1 (Dense)             (None, None, 13676)          7015788   ['concat_layer[0][0]']
#
# ==================================================================================================
# Total params: 14685164 (56.02 MB)
# Trainable params: 14685164 (56.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', patience=2, verbose=1)
history = model.fit(x=[encoder_input_train, decoder_input_train], y=decoder_target_train,
                    validation_data=([encoder_input_test, decoder_input_test], decoder_target_test),
                    batch_size=256, callbacks=[es], epochs=50)
# Out:
# Epoch 1/50
# 308/308 [==============================] - 65s 183ms/step - loss: 4.8313 - val_loss: 4.4957
# Epoch 2/50
# 308/308 [==============================] - 58s 189ms/step - loss: 4.5391 - val_loss: 4.4464
# Epoch 3/50
# 308/308 [==============================] - 59s 192ms/step - loss: 4.4683 - val_loss: 4.3627
# Epoch 4/50
# 308/308 [==============================] - 59s 192ms/step - loss: 4.3712 - val_loss: 4.2760
# Epoch 5/50
# 308/308 [==============================] - 59s 192ms/step - loss: 4.2804 - val_loss: 4.2072
# Epoch 6/50
# 308/308 [==============================] - 59s 192ms/step - loss: 4.1956 - val_loss: 4.1280
# Epoch 7/50
# 308/308 [==============================] - 59s 193ms/step - loss: 4.1129 - val_loss: 4.0407
# Epoch 8/50
# 308/308 [==============================] - 59s 193ms/step - loss: 4.0318 - val_loss: 3.9690
# Epoch 9/50
# 308/308 [==============================] - 59s 192ms/step - loss: 3.9459 - val_loss: 3.8945
# Epoch 10/50
# 308/308 [==============================] - 59s 192ms/step - loss: 3.8636 - val_loss: 3.8252
# Epoch 11/50
# 308/308 [==============================] - 59s 192ms/step - loss: 3.7898 - val_loss: 3.7745
# Epoch 12/50
# 308/308 [==============================] - 59s 193ms/step - loss: 3.7262 - val_loss: 3.7272
# Epoch 13/50
# 308/308 [==============================] - 59s 193ms/step - loss: 3.6686 - val_loss: 3.6708
# Epoch 14/50
# 308/308 [==============================] - 59s 193ms/step - loss: 3.6161 - val_loss: 3.6418
# Epoch 15/50
# 308/308 [==============================] - 59s 192ms/step - loss: 3.5666 - val_loss: 3.6103
# Epoch 16/50
# 308/308 [==============================] - 59s 193ms/step - loss: 3.5169 - val_loss: 3.5865
# Epoch 17/50
# 308/308 [==============================] - 59s 193ms/step - loss: 3.4679 - val_loss: 3.5359
# Epoch 18/50
# 308/308 [==============================] - 59s 193ms/step - loss: 3.4210 - val_loss: 3.5082
# Epoch 19/50
# 308/308 [==============================] - 59s 193ms/step - loss: 3.3755 - val_loss: 3.4792
# Epoch 20/50
# 308/308 [==============================] - 59s 193ms/step - loss: 3.3306 - val_loss: 3.4344
# Epoch 21/50
# 308/308 [==============================] - 59s 193ms/step - loss: 3.2880 - val_loss: 3.4127
# Epoch 22/50
# 308/308 [==============================] - 59s 193ms/step - loss: 3.2460 - val_loss: 3.3847
# Epoch 23/50
# 308/308 [==============================] - 59s 193ms/step - loss: 3.2058 - val_loss: 3.3621
# Epoch 24/50
# 308/308 [==============================] - 59s 193ms/step - loss: 3.1674 - val_loss: 3.3424
# Epoch 25/50
# 308/308 [==============================] - 59s 193ms/step - loss: 3.1300 - val_loss: 3.3179
# Epoch 26/50
# 308/308 [==============================] - 59s 193ms/step - loss: 3.0937 - val_loss: 3.2911
# Epoch 27/50
# 308/308 [==============================] - 59s 193ms/step - loss: 3.0595 - val_loss: 3.2858
# Epoch 28/50
# 308/308 [==============================] - 59s 193ms/step - loss: 3.0257 - val_loss: 3.2583
# Epoch 29/50
# 308/308 [==============================] - 59s 193ms/step - loss: 2.9939 - val_loss: 3.2436
# Epoch 30/50
# 308/308 [==============================] - 59s 193ms/step - loss: 2.9626 - val_loss: 3.2336
# Epoch 31/50
# 308/308 [==============================] - 59s 193ms/step - loss: 2.9333 - val_loss: 3.2166
# Epoch 32/50
# 308/308 [==============================] - 59s 192ms/step - loss: 2.9039 - val_loss: 3.2042
# Epoch 33/50
# 308/308 [==============================] - 59s 192ms/step - loss: 2.8759 - val_loss: 3.1927
# Epoch 34/50
# 308/308 [==============================] - 59s 193ms/step - loss: 2.8492 - val_loss: 3.1731
# Epoch 35/50
# 308/308 [==============================] - 59s 193ms/step - loss: 2.8233 - val_loss: 3.1679
# Epoch 36/50
# 308/308 [==============================] - 60s 193ms/step - loss: 2.7968 - val_loss: 3.1642
# Epoch 37/50
# 308/308 [==============================] - 59s 193ms/step - loss: 2.7718 - val_loss: 3.1541
# Epoch 38/50
# 308/308 [==============================] - 59s 193ms/step - loss: 2.7472 - val_loss: 3.1385
# Epoch 39/50
# 308/308 [==============================] - 59s 193ms/step - loss: 2.7234 - val_loss: 3.1321
# Epoch 40/50
# 308/308 [==============================] - 59s 193ms/step - loss: 2.7004 - val_loss: 3.1331
# Epoch 41/50
# 308/308 [==============================] - 59s 193ms/step - loss: 2.6773 - val_loss: 3.1183
# Epoch 42/50
# 308/308 [==============================] - 59s 193ms/step - loss: 2.6552 - val_loss: 3.1192
# Epoch 43/50
# 308/308 [==============================] - 59s 193ms/step - loss: 2.6337 - val_loss: 3.1052
# Epoch 44/50
# 308/308 [==============================] - 59s 193ms/step - loss: 2.6118 - val_loss: 3.0958
# Epoch 45/50
# 308/308 [==============================] - 59s 193ms/step - loss: 2.5912 - val_loss: 3.0945
# Epoch 46/50
# 308/308 [==============================] - 59s 193ms/step - loss: 2.5705 - val_loss: 3.0913
# Epoch 47/50
# 308/308 [==============================] - 59s 193ms/step - loss: 2.5504 - val_loss: 3.0889
# Epoch 48/50
# 308/308 [==============================] - 59s 193ms/step - loss: 2.5312 - val_loss: 3.0872
# Epoch 49/50
# 308/308 [==============================] - 60s 193ms/step - loss: 2.5115 - val_loss: 3.0762
# Epoch 50/50
# 308/308 [==============================] - 59s 193ms/step - loss: 2.4926 - val_loss: 3.0763

# %%
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음


encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)
# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])


# 어텐션 함수
decoder_hidden_state_input = Input(shape=(max_text_len, hidden_size))
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat)

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # 입력으로부터 인코더의 상태를 얻음
    e_out, e_h, e_c = encoder_model.predict(input_seq)

     # <SOS>에 해당하는 토큰 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['starttoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if(sampled_token!='endtoken'):
            decoded_sentence += ' '+sampled_token

        #  <eos>에 도달하거나 최대 길이를 넘으면 중단.
        if (sampled_token == 'endtoken'  or len(decoded_sentence.split()) >= (max_headline_len-1)):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 상태를 업데이트 합니다.
        e_h, e_c = h, c

    return decoded_sentence

# %%
# tar_word_to_index.update({'wht?' : 0})
# tar_index_to_word.update({0 : 'wht?'})

# def decode_sequence2(input_seq):
#   # 입력으로부터 인코더의 상태를 얻음
#   e_out, e_h, e_c = encoder_model.predict(input_seq)

#   # <SOS>에 해당하는 토큰 생성
#   target_seq = np.zeros((1,1))
#   target_seq[0,0] = tar_word_to_index['starttoken']

#   stop_condition = False
#   decoded_sentence = ''
#   while not stop_condition:

#     output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
#     sampled_token_index = np.argmax(output_tokens[0, -1, :])

#     sampled_token = tar_index_to_word[sampled_token_index]

#     if (sampled_token != 'endtoken'):
#       decoded_sentence += ' '+sampled_token

#     # <EOS>에 도달하거나 최대 길이를 넘으면 중단.
#     if (sampled_token == 'endtoken' or len(decoded_sentence.split()) >= (max_headline_len - 1)):
#       stop_condition = True

#     # 길이가 1인 타겟 시퀀스를 업데이트
#     target_seq = np.zeros((1,1))
#     target_seq[0,0] = sampled_token_index

#     # 상태를 업데이트 합니다.
#     e_h, e_c = h, c

#   return decoded_sentence

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2text(input_seq):
    temp=''
    for i in input_seq:
        if(i!=0):
            temp = temp + src_index_to_word[i]+' '
    return temp

# 요약문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2summary(input_seq):
    temp=''
    for i in input_seq:
        if((i!=0 and i!=tar_word_to_index['starttoken']) and i!=tar_word_to_index['endtoken']):
            temp = temp + tar_index_to_word[i] + ' '
    return temp

# %%
for i in range(50, 60):
    print("원문 :", seq2text(encoder_input_test[i]))
    print("실제 요약 :", seq2summary(decoder_input_test[i]))
    print("예측 요약 :", decode_sequence(encoder_input_test[i].reshape(1, max_text_len)))
    print("\n")
# Out:
# 원문 : congress leader former mp chaturvedi friday claimed publicly asked congress expel son denied ticket stating congress making star campaigner said unable understand party fuctioning sad removing son nitin chaturvedi contesting smajwadi party ticket
# 실제 요약 : told congress to expel me as son was denied ticket ex mp
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 예측 요약 :  congress mp shares video of congress mp
#
#
# 원문 : national green tribunal tuesday questioned delhi government inffective implementation plastic ban city crtcising government easy valability plastic warned action order better implmented ngt banned using disposable plastic delhi ncr january year
# 실제 요약 : plastic ban not implmented ngt to delhi govt
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 예측 요약 :  ngt bans ban on sale of plastic ban on sale to ban
#
#
# 원문 : astronomers dtected first radioactive molecule space blieved stellar explosion visible 17th century naked eye molecule aluminium made aluminium 26 radioactive isotope aluminium explosion resulted merger two stars creating red new class stars
# 실제 요약 : cientists find radioactive in space for 1st time
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 예측 요약 :  cientists discover new first ever system
#
#
# 원문 : new delhi municipal council started process auctioning three premium hotels located lutyens area including taj mahal hotel road reports quoting officials said hotels leased private operators period 33 years bids accepted may 15 june
# 실제 요약 : delhi municipal body to auction taj other hotels
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 예측 요약 :  delhi to get sanitary machines to improve
#
#
# 원문 : actress deepika padukone rvealed slapped man alegedly misbehaved street 14 years old said man brushed past could point ignored prtended like happen deepika said day parents knew take care
# 실제 요약 : slapped man who misbehaved with me when was 14 deepika
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 예측 요약 :  my life was told to shoot with my life deepika
#
#
# 원문 : yogi dityanath led government tuesday renamed agra gorakhpur airports cabinet meet gorakhpur airport renamed gorakhnath airport founder nath movement agra airport named rss ideologue pandit deen dayal upadhyay futhermore department disabled welfare called jan vikas mpowerment
# 실제 요약 : yogi dityanath govt renames agra gorakhpur airports
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 예측 요약 :  up govt to give 5l for to kids victims victims
#
#
# 원문 : images surfaced online wherein students uttrakhand chamoli could seen climbing small hill using rope ladder reach school students use risky medium bridge river swept away heavy rainfall monday nearly 12 houses ten shops six vehicles swept away rain
# 실제 요약 : students climb hill using rope ladder to reach school
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 예측 요약 :  up students to be renamed after diwali
#
#
# 원문 : britain wednesday said mistakenly sent dozens letters telling european union nationals leave country adding rights eu nationals living uk remain unchanged officials said contacting veryone rceived letter clarify disregard notably britain promised generous deal eu citizens following brexit
# 실제 요약 : britain mistakenly tells dozens of eu citizens to leave
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 예측 요약 :  uk to ban on brexit status
#
#
# 원문 : elon musk led spacex rocket engine exploded qualfication test facility us last week space exploration startup confirmed wednesday merlin engine intended used falcon rocket launch 2018 spacex said person injured aded nvestigating cause explosion
# 실제 요약 : spacex rocket engine explodes during test in us
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 예측 요약 :  spacex rocket rocket rocket rocket fails to launch
#
#
# 원문 : german electric vehicle startup planing invest around 15 million set manufacturing base andhra pradesh startup ceo hubert recently met andhra pradesh chief minister chndrababu naidu dicuss startup reportedly proposed supply battery powered vehicles 15 590 price range
# 실제 요약 : german ev startup to invest 15 mn in india
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 예측 요약 :  startup to invest cr in india to raise 500 cr in india

# %%
tar_index_to_word
# Out:
# {1: 'starttoken',
#  2: 'endtoken',
#  3: 'to',
#  4: 'in',
#  5: 'for',
#  6: 'of',
#  7: 'on',
#  8: 'india',
#  9: 'with',
#  10: 'not',
#  11: 'at',
#  12: 'after',
#  13: 'us',
#  14: 'over',
#  15: 'from',
#  16: 'as',
#  17: 'by',
#  18: 'the',
#  19: 'is',
#  20: 'man',
#  21: 'be',
#  22: 'pm',
#  23: 'will',
#  24: 'govt',
#  25: 'up',
#  26: 'old',
#  27: 'delhi',
#  28: 'world',
#  29: 'indian',
#  30: 'trump',
#  31: 'was',
#  32: 'bjp',
#  33: 'crore',
#  34: 'cm',
#  35: 'report',
#  36: 'woman',
#  37: 'new',
#  38: 'modi',
#  39: 'who',
#  40: 'year',
#  41: '1st',
#  42: 'his',
#  43: 'against',
#  44: 'no',
#  45: 'first',
#  46: 'have',
#  47: 'it',
#  48: 'and',
#  49: '00',
#  50: 'my',
#  51: 'ex',
#  52: 'out',
#  53: 'day',
#  54: 'time',
#  55: 'mumbai',
#  56: 'film',
#  57: '10',
#  58: 'pak',
#  59: 'do',
#  60: 'china',
#  61: 'years',
#  62: 'people',
#  63: 'yr',
#  64: 'police',
#  65: 'reports',
#  66: 'sc',
#  67: 'case',
#  68: 'women',
#  69: 'ceo',
#  70: 'get',
#  71: 'lakh',
#  72: 'gets',
#  73: 'me',
#  74: 'killed',
#  75: 'rahul',
#  76: 'video',
#  77: 'are',
#  78: 'minister',
#  79: 'has',
#  80: 'startup',
#  81: 'if',
#  82: 'its',
#  83: 'cr',
#  84: 'can',
#  85: 'chief',
#  86: 'arrested',
#  87: 'may',
#  88: 'her',
#  89: 'that',
#  90: 'says',
#  91: 'test',
#  92: 'uk',
#  93: 'google',
#  94: 'win',
#  95: 'like',
#  96: 'team',
#  97: 'found',
#  98: 'death',
#  99: 'into',
#  100: 'kohli',
#  101: 'all',
#  102: 'mp',
#  103: 'made',
#  104: 'during',
#  105: 'pakistan',
#  106: 'record',
#  107: 'air',
#  108: 'prez',
#  109: 'he',
#  110: 'being',
#  111: 'we',
#  112: 'congress',
#  113: 'hc',
#  114: 'shares',
#  115: 'korea',
#  116: 'wife',
#  117: 'one',
#  118: '100',
#  119: 'leader',
#  120: 'him',
#  121: 'girl',
#  122: 'you',
#  123: 'off',
#  124: 'post',
#  125: 'car',
#  126: 'held',
#  127: 'most',
#  128: 'only',
#  129: 'make',
#  130: 'study',
#  131: 'dead',
#  132: 'bank',
#  133: 'yrs',
#  134: 'son',
#  135: 'apple',
#  136: 'cong',
#  137: 'kerala',
#  138: 'what',
#  139: 'attack',
#  140: 'more',
#  141: 'asks',
#  142: 'than',
#  143: 'court',
#  144: 'am',
#  145: 'ban',
#  146: 'accused',
#  147: 'days',
#  148: 'player',
#  149: 'should',
#  150: 'users',
#  151: 'body',
#  152: 'did',
#  153: '20',
#  154: 'rape',
#  155: 'russia',
#  156: 'pic',
#  157: 'pay',
#  158: 'about',
#  159: 'raises',
#  160: 'khan',
#  161: 'witter',
#  162: '2018',
#  163: 'match',
#  164: 'an',
#  165: 'calls',
#  166: 'wins',
#  167: 'firm',
#  168: 'facebook',
#  169: 'un',
#  170: '12',
#  171: 'before',
#  172: 'army',
#  173: 'take',
#  174: 'cannot',
#  175: 'hit',
#  176: 'open',
#  177: '11',
#  178: 'claims',
#  179: 'fake',
#  180: 'home',
#  181: 'president',
#  182: 'tweets',
#  183: 'launches',
#  184: 'two',
#  185: 'down',
#  186: 'billion',
#  187: '15',
#  188: 'how',
#  189: 'star',
#  190: 'million',
#  191: 'due',
#  192: 'salman',
#  193: 'dies',
#  194: 'show',
#  195: 'data',
#  196: 'life',
#  197: 'school',
#  198: 'airport',
#  199: 'uber',
#  200: '50',
#  201: 'house',
#  202: 'actor',
#  203: 'worth',
#  204: 'fire',
#  205: 'students',
#  206: 'play',
#  207: 'under',
#  208: 'men',
#  209: 'last',
#  210: 'party',
#  211: 'state',
#  212: 'gandhi',
#  213: 'dhoni',
#  214: 'cricket',
#  215: 'slams',
#  216: 'family',
#  217: 'ipl',
#  218: 'hits',
#  219: 'why',
#  220: 'bihar',
#  221: 'ever',
#  222: 'train',
#  223: '30',
#  224: 'daughter',
#  225: '2017',
#  226: 'priyanka',
#  227: 'would',
#  228: 'top',
#  229: 'work',
#  230: 'deal',
#  231: 'becomes',
#  232: 'singh',
#  233: 'back',
#  234: 'run',
#  235: 'jail',
#  236: 'mn',
#  237: 'now',
#  238: 'their',
#  239: 'flight',
#  240: 'kids',
#  241: 'free',
#  242: 'cup',
#  243: 'row',
#  244: 'using',
#  245: 'user',
#  246: 'does',
#  247: 'former',
#  248: 'sexual',
#  249: 'takes',
#  250: 'gold',
#  251: 'cbi',
#  252: 'when',
#  253: 'polls',
#  254: 'founder',
#  255: 'months',
#  256: 'without',
#  257: 'gst',
#  258: 'centre',
#  259: 'use',
#  260: 'saudi',
#  261: 'wedding',
#  262: 'protest',
#  263: 'launch',
#  264: 'help',
#  265: 'want',
#  266: 'go',
#  267: 'used',
#  268: '500',
#  269: 'give',
#  270: 'away',
#  271: 'chinese',
#  272: 'app',
#  273: 'bn',
#  274: 'actress',
#  275: 'amid',
#  276: 'shows',
#  277: 'captain',
#  278: 'shah',
#  279: 'makes',
#  280: 'money',
#  281: 'musk',
#  282: 'set',
#  283: 'sachin',
#  284: 'runs',
#  285: 'had',
#  286: 'government',
#  287: 'taka',
#  288: 'iran',
#  289: 'mla',
#  290: 'odi',
#  291: 'this',
#  292: 'bengaluru',
#  293: 'rleased',
#  294: 'injured',
#  295: 'probe',
#  296: 'while',
#  297: 'named',
#  298: 'head',
#  299: 'own',
#  300: 'big',
#  301: 'sex',
#  302: 'amazon',
#  303: 'father',
#  304: 'kills',
#  305: 'media',
#  306: 'ram',
#  307: 'nasa',
#  308: '17',
#  309: 'anti',
#  310: 'war',
#  311: 'srk',
#  312: 'ustralia',
#  313: 'our',
#  314: '18',
#  315: 'best',
#  316: 'suicide',
#  317: 'wc',
#  318: 'boy',
#  319: 'mother',
#  320: 'face',
#  321: 'series',
#  322: 'aus',
#  323: 'law',
#  324: '16',
#  325: 'fb',
#  326: 'student',
#  327: 'could',
#  328: '13',
#  329: '25',
#  330: 'security',
#  331: '2nd',
#  332: 'tv',
#  333: 'denies',
#  334: 'since',
#  335: 'cops',
#  336: 'staff',
#  337: 'tax',
#  338: 'online',
#  339: 'baby',
#  340: 'name',
#  341: 'seeks',
#  342: 'dhaar',
#  343: 'bill',
#  344: 'space',
#  345: 'krntaka',
#  346: 'song',
#  347: 'gujarat',
#  348: 'ranveer',
#  349: 'rbi',
#  350: 'national',
#  351: 'but',
#  352: 'russian',
#  353: 'self',
#  354: 'which',
#  355: 'food',
#  356: 'north',
#  357: 'co',
#  358: 'murder',
#  359: 'high',
#  360: 'once',
#  361: 'harassment',
#  362: 'andhra',
#  363: 'stop',
#  364: 'class',
#  365: 'look',
#  366: 'largest',
#  367: '200',
#  368: '19',
#  369: 'deepika',
#  370: 'hospital',
#  371: 'board',
#  372: 'never',
#  373: 'tesla',
#  374: 'goes',
#  375: 'plane',
#  376: 'cientists',
#  377: 'end',
#  378: 'maha',
#  379: 'south',
#  380: 'got',
#  381: 'shot',
#  382: 'water',
#  383: 'kapoor',
#  384: 'highest',
#  385: 'coach',
#  386: 'rlease',
#  387: 'become',
#  388: 'plans',
#  389: 'bans',
#  390: 'punjab',
#  391: 'isis',
#  392: 'child',
#  393: '2019',
#  394: 'posts',
#  395: 'sets',
#  396: 'gives',
#  397: 'were',
#  398: 'game',
#  399: 'times',
#  400: 'next',
#  401: '14',
#  402: 'couple',
#  403: 'ball',
#  404: 'tn',
#  405: 'offers',
#  406: 'loses',
#  407: 'asked',
#  408: 'or',
#  409: 'husband',
#  410: 'buy',
#  411: 'japan',
#  412: 'flipkart',
#  413: 'missing',
#  414: '40',
#  415: 'falls',
#  416: 'director',
#  417: 'final',
#  418: 'mhrashtra',
#  419: 'sale',
#  420: 'temple',
#  421: 'pases',
#  422: 'public',
#  423: 'akshay',
#  424: 'list',
#  425: 'news',
#  426: 'told',
#  427: 'starer',
#  428: 'aap',
#  429: 'biggest',
#  430: 'driver',
#  431: 'kumar',
#  432: 'month',
#  433: 'orders',
#  434: 'cop',
#  435: 'bus',
#  436: 'she',
#  437: 'group',
#  438: 'fight',
#  439: 'kngana',
#  440: 'indians',
#  441: 'anounces',
#  442: 'must',
#  443: 'virat',
#  444: 'love',
#  445: 'sena',
#  446: 'near',
#  447: 'call',
#  448: 'there',
#  449: 'tech',
#  450: 'visit',
#  451: 'need',
#  452: '300',
#  453: 'whatsapp',
#  454: 'award',
#  455: 'company',
#  456: 'debut',
#  457: 'england',
#  458: 'workers',
#  459: 'working',
#  460: 'human',
#  461: 'cut',
#  462: 'let',
#  463: 'french',
#  464: 'based',
#  465: 'talks',
#  466: 'goa',
#  467: 'breaks',
#  468: 'road',
#  469: 'judge',
#  470: 'yogi',
#  471: 'officer',
#  472: 'ronaldo',
#  473: 'loss',
#  474: 'bcci',
#  475: 'ai',
#  476: 'power',
#  477: 'fan',
#  478: 'live',
#  479: 'phone',
#  480: 'pradesh',
#  481: 'good',
#  482: 'teror',
#  483: 'notice',
#  484: 'black',
#  485: 'city',
#  486: 'nuclear',
#  487: 'hryana',
#  488: 'strike',
#  489: 'fraud',
#  490: 'beat',
#  491: 'remark',
#  492: 'female',
#  493: 'fans',
#  494: 'players',
#  495: 'hotel',
#  496: 'meet',
#  497: 'rjasthan',
#  498: 'been',
#  499: 'firms',
#  500: 'birthday',
#  501: 'films',
#  502: 'cars',
#  503: 'jaitley',
#  504: 'they',
#  505: 'kejriwal',
#  506: 'files',
#  507: 'station',
#  508: 'driving',
#  509: 'leave',
#  510: 'led',
#  511: 'jailed',
#  512: 'booked',
#  513: 'change',
#  514: 'muslim',
#  515: '3rd',
#  516: 'reveals',
#  517: 'lost',
#  518: 'marriage',
#  519: 'metro',
#  520: 'mployees',
#  521: 'ranbir',
#  522: 'just',
#  523: 'tweet',
#  524: 'part',
#  525: 'return',
#  526: 'plan',
#  527: 'kill',
#  528: 'kashmir',
#  529: 'london',
#  530: 'paid',
#  531: 'cases',
#  532: 'earth',
#  533: 'second',
#  534: 'support',
#  535: 'ahead',
#  536: 'isues',
#  537: 'real',
#  538: 'farmers',
#  539: 'kapil',
#  540: 'raj',
#  541: 'called',
#  542: 'football',
#  543: 'chairman',
#  544: 'girls',
#  545: 'pics',
#  546: 'office',
#  547: 'syria',
#  548: 'victim',
#  549: 'viral',
#  550: 'issue',
#  551: 'military',
#  552: 'tests',
#  553: 'jet',
#  554: 'trailer',
#  555: 'banks',
#  556: 'foreign',
#  557: 'rohit',
#  558: 'putin',
#  559: '24',
#  560: 'apologises',
#  561: 'brother',
#  562: 'sell',
#  563: 'anushka',
#  564: 'even',
#  565: 'plea',
#  566: 'official',
#  567: 'scam',
#  568: 'see',
#  569: 'sharma',
#  570: 'quits',
#  571: 'union',
#  572: 'sri',
#  573: 'bitcoin',
#  574: 'vs',
#  575: 'same',
#  576: 'hours',
#  577: 'sehwag',
#  578: 'wrong',
#  579: 'making',
#  580: 'them',
#  581: 'tamil',
#  582: 'country',
#  583: 'every',
#  584: '22',
#  585: 'claim',
#  586: 'buiness',
#  587: 'arrest',
#  588: 'cancer',
#  589: 'event',
#  590: 'funding',
#  591: 'railways',
#  592: 'attacks',
#  593: 'three',
#  594: 'right',
#  595: 'model',
#  596: 'rejects',
#  597: 'ago',
#  598: 'alia',
#  599: 'feature',
#  600: 'schools',
#  601: 'iphone',
#  602: 'other',
#  603: 'service',
#  604: 'week',
#  605: 'lose',
#  606: 'race',
#  607: 'tata',
#  608: 'stake',
#  609: 'border',
#  610: 'teen',
#  611: 'history',
#  612: 'rss',
#  613: 'fund',
#  614: 'unveils',
#  615: 'system',
#  616: 'job',
#  617: 'fghanistan',
#  618: 'given',
#  619: 'suspended',
#  620: 'each',
#  621: 'your',
#  622: 'order',
#  623: '400',
#  624: 'shut',
#  625: 'sonam',
#  626: 'mallya',
#  627: 'kim',
#  628: 'luru',
#  629: 'poster',
#  630: 'refuses',
#  631: 'instagram',
#  632: 'ilegal',
#  633: 'title',
#  634: 'parliament',
#  635: 'fined',
#  636: 'global',
#  637: 'sold',
#  638: 'children',
#  639: 'find',
#  640: 'raped',
#  641: 'watch',
#  642: 'protests',
#  643: 'johar',
#  644: 'poll',
#  645: 'warns',
#  646: 'late',
#  647: 'rises',
#  648: 'come',
#  649: 'min',
#  650: 'crash',
#  651: 'france',
#  652: 'kg',
#  653: '26',
#  654: 'oil',
#  655: 'minor',
#  656: 'through',
#  657: 'move',
#  658: 'role',
#  659: 'aamir',
#  660: 'meeting',
#  661: 'gurugram',
#  662: 'assembly',
#  663: 'exam',
#  664: '21',
#  665: 'mlas',
#  666: 'cash',
#  667: 'slammed',
#  668: 'killing',
#  669: 'elections',
#  670: 'social',
#  671: 'nirav',
#  672: 'banned',
#  673: 'note',
#  674: 'jobs',
#  675: 'raping',
#  676: 'violence',
#  677: 'election',
#  678: 'among',
#  679: 'bomb',
#  680: 'building',
#  681: 'drug',
#  682: 'land',
#  683: 'dog',
#  684: 'behind',
#  685: 'any',
#  686: 'states',
#  687: 'white',
#  688: 'number',
#  689: 'despite',
#  690: 'birth',
#  691: 'rules',
#  692: 'arjun',
#  693: 'israel',
#  694: 'build',
#  695: 'die',
#  696: 'non',
#  697: 'lalu',
#  698: 'wanted',
#  699: 'bllionaire',
#  700: 'health',
#  701: 'ambani',
#  702: 'cnada',
#  703: 'club',
#  704: 'officials',
#  705: 'way',
#  706: 'wood',
#  707: 'btween',
#  708: 'infosys',
#  709: 'elon',
#  710: 'tiger',
#  711: 'profit',
#  712: 'origin',
#  713: 'int',
#  714: 'too',
#  715: 'theatres',
#  716: 't20i',
#  717: 'dad',
#  718: 'won',
#  719: 'score',
#  720: 'hai',
#  721: 'photo',
#  722: 'names',
#  723: 'action',
#  724: 'said',
#  725: 'panel',
#  726: 'still',
#  727: 'bharat',
#  728: 'till',
#  729: 'trade',
#  730: 'triple',
#  731: 'wining',
#  732: 'better',
#  733: '70',
#  734: 'missile',
#  735: 'korean',
#  736: 'fir',
#  737: 'approves',
#  738: 'hindu',
#  739: 'km',
#  740: 'know',
#  741: 'scores',
#  742: 'statue',
#  743: 'donald',
#  744: 'moon',
#  745: 'odisha',
#  746: 'ali',
#  747: 'mom',
#  748: 'career',
#  749: 'leaders',
#  750: 'lead',
#  751: 'sabha',
#  752: 'railway',
#  753: 'west',
#  754: 'assam',
#  755: 'karan',
#  756: 'threat',
#  757: 'sues',
#  758: 'messi',
#  759: 'special',
#  760: 'victims',
#  761: 'hold',
#  762: 'together',
#  763: 'long',
#  764: 'uses',
#  765: 'airline',
#  766: 'took',
#  767: 'amit',
#  768: 'iit',
#  769: 'join',
#  770: 'sends',
#  771: 'bail',
#  772: 'allows',
#  773: 'yadav',
#  774: 'quit',
#  775: 'inside',
#  776: 'taking',
#  777: 'dfence',
#  778: 'ustralian',
#  779: 'accident',
#  780: 'parents',
#  781: 'reach',
#  782: 'girlfriend',
#  783: 'trying',
#  784: 'tells',
#  785: 'german',
#  786: 'microsoft',
#  787: 'rleases',
#  788: 'goal',
#  789: 'sridevi',
#  790: 'term',
#  791: 'hyderabad',
#  792: 'drunk',
#  793: 'youth',
#  794: 'mobile',
#  795: 'forced',
#  796: 'offer',
#  797: 'beats',
#  798: 'demands',
#  799: 'price',
#  800: '60',
#  801: 'person',
#  802: 'political',
#  803: 'getting',
#  804: 'march',
#  805: 'miss',
#  806: 'germany',
#  807: 'katrina',
#  808: 'buys',
#  809: 'left',
#  810: 'break',
#  811: 'bengal',
#  812: 'playing',
#  813: 'accuses',
#  814: 'loan',
#  815: 'mployee',
#  816: 'so',
#  817: '2016',
#  818: 'ready',
#  819: 'boss',
#  820: 'smith',
#  821: 'ad',
#  822: 'icc',
#  823: 'fine',
#  824: 'trolls',
#  825: 'secy',
#  826: 'terorists',
#  827: 'book',
#  828: 'picture',
#  829: 'sister',
#  830: 'fifa',
#  831: 'force',
#  832: 'cow',
#  833: 'records',
#  834: 'another',
#  835: 'lawyer',
#  836: 'put',
#  837: 'maker',
#  838: 'swaraj',
#  839: 'pnb',
#  840: 'share',
#  841: 'third',
#  842: 'save',
#  843: 'store',
#  844: 'shahid',
#  845: 'sent',
#  846: 'very',
#  847: 'returns',
#  848: 'outside',
#  849: 'varun',
#  850: 'games',
#  851: 'cuts',
#  852: 'assault',
#  853: 'seized',
#  854: 'mmata',
#  855: 'date',
#  856: 'rights',
#  857: 'eu',
#  858: 'aged',
#  859: 'resigns',
#  860: 'cost',
#  861: 'married',
#  862: '23',
#  863: 'market',
#  864: 'bad',
#  865: 'private',
#  866: 'awards',
#  867: 'abuse',
#  868: 'paytm',
#  869: 'opens',
#  870: 'mergency',
#  871: 'reliance',
#  872: 'friend',
#  873: 'asia',
#  874: 'today',
#  875: 'those',
#  876: 'university',
#  877: 'biopic',
#  878: 'again',
#  879: 'paris',
#  880: 'corruption',
#  881: 'charges',
#  882: 'less',
#  883: 'helps',
#  884: 'raise',
#  885: 'toilet',
#  886: 'anil',
#  887: 'start',
#  888: 'talaq',
#  889: 'threatens',
#  890: 'policy',
#  891: 'teacher',
#  892: 'hindi',
#  893: 'letter',
#  894: 'great',
#  895: 'sl',
#  896: 'singer',
#  897: 'electric',
#  898: 'fderer',
#  899: 'faces',
#  900: 'pilot',
#  901: 'selling',
#  902: 'forces',
#  903: 'wb',
#  904: 'speech',
#  905: 'liquor',
#  906: 'rafale',
#  907: 'campaign',
#  908: 'telngana',
#  909: 'travel',
#  910: '35',
#  911: 'much',
#  912: 'sbi',
#  913: 'ed',
#  914: 'vote',
#  915: 'kin',
#  916: 'softbank',
#  917: 'sanctions',
#  918: 'traffic',
#  919: 'per',
#  920: 'kolkata',
#  921: 'cover',
#  922: 'finds',
#  923: 'ton',
#  924: 'noida',
#  925: 'pays',
#  926: 'say',
#  927: 'village',
#  928: 'cricketer',
#  929: 'challenge',
#  930: 'airways',
#  931: 'nadu',
#  932: 'tharoor',
#  933: 'act',
#  934: 'ship',
#  935: 'british',
#  936: 'fired',
#  937: 'caught',
#  938: 'asian',
#  939: 'fastest',
#  940: 'shooting',
#  941: 'mars',
#  942: 'age',
#  943: 'wickets',
#  944: 'jio',
#  945: 'met',
#  946: 'card',
#  947: 'himself',
#  948: 'died',
#  949: 'doctors',
#  950: 'allow',
#  951: 'mark',
#  952: 'shiv',
#  953: 'single',
#  954: 'music',
#  955: 'think',
#  956: 'journo',
#  957: 'low',
#  958: 'ends',
#  959: 'demand',
#  960: 'internet',
#  961: '600',
#  962: 'fashion',
#  963: 'host',
#  964: 'wants',
#  965: 'starts',
#  966: 'mps',
#  967: 'seats',
#  968: 'dance',
#  969: 'wishes',
#  970: 'stolen',
#  971: 'crashes',
#  972: 'pune',
#  973: 'nobel',
#  974: 'stay',
#  975: 'governor',
#  976: 'contest',
#  977: 'kareena',
#  978: 'complaint',
#  979: 'cwg',
#  980: 'track',
#  981: 'sa',
#  982: 'doing',
#  983: 'jong',
#  984: 'bar',
#  985: 'half',
#  986: 'notes',
#  987: 'catch',
#  988: 'fall',
#  989: 'straight',
#  990: 'remove',
#  991: 'attend',
#  992: 'stock',
#  993: 'ganguly',
#  994: 'charge',
#  995: 'owner',
#  996: 'send',
#  997: 'ms',
#  998: 'ec',
#  999: 'doctor',
#  1000: 'guj',
#  ...}
