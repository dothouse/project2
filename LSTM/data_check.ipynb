# %%
from google.colab import drive
drive.mount('/content/drive')

base_path = '/content/drive/MyDrive/new_project/project2'
data_path = '/content/drive/MyDrive/new_project/project2/traindata/문서요약 텍스트/'


#  https://github.com/uoneway/Text-Summarization-Repo?tab=readme-ov-file
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv(f'{data_path}all_dataset.csv')
df.head()
# Out:
#           id category media_type media_sub_type media_name  char_count  \
# 0  290741778       종합     online            지역지       광양신문         927
# 1  290741792       종합     online            지역지       광양신문         764
# 2  290741793      스포츠     online            지역지       광양신문        1066
# 3  290741794       정치     online            지역지       광양신문         746
# 4  290741797       종합     online            지역지       광양신문         978
#
#           publish_date                          title  \
# 0  2018-01-05 18:54:55         논 타작물 재배, 2월 말까지 신청하세요
# 1  2018-01-05 18:53:20  여수시, 컬러빌리지 마무리...‘색채와 빛’도시 완성
# 2  2018-01-05 18:52:15        “새해 정기 받고 올해는 반드시 일내자!”
# 3  2018-01-05 18:50:17          농업인 역량 강화, 새해 실용교육 실시
# 4  2018-01-05 18:52:36          타이완 크루즈관광객 4천여명‘전남’온다
#
#                                          abstractive  \
# 0  전라남도가 쌀 과잉문제를 근본적으로 해결하기 위해 올해부터 벼를 심었던 논에 벼 대...
# 1  여수시는 컬러빌리지 사업에 8억원을 투입하여 ‘색채와 빛’ 도시를 완성하여 고소천사...
# ...

# %%
print(df['category'].nunique())
print(df['category'].unique())
# Out:
# 8
# ['종합' '스포츠' '정치' '사회' '경제' '교육/입시/NIE' '선거' '기업']

# %%
print(df['media_name'].nunique())
print(df['media_name'].unique())
# Out:
# 3
# ['광양신문' '광주매일신문' '광주일보']

# %%
df[df['dataset'] == 'valid']
# Out:
# Empty DataFrame
# Columns: [id, category, media_type, media_sub_type, media_name, char_count, publish_date, title, abstractive, text_all, text_sentence, score_read, score_acc, score_info, score_trust, extractive, dataset]
# Index: []
